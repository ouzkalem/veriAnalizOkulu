# %% [markdown]
# <a href="https://colab.research.google.com/github/ouzkalem/veriAnalizOkulu/blob/main/DLSG_Exercise_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Colab'a hoş geldiniz.

# %% [markdown]
# # WEEK 2: Deep Learning Fundamentals with Fashion  v2 denemsi

# %% [markdown]
# ## LEARNING OBJECTIVES
# By the end of this exercise, you will be able to:
# 1. Load and preprocess image data using PyTorch's DataLoader
# 2. Design a feedforward neural network architecture
# 3. Implement a complete training loop with forward/backward propagation
# 4. Apply regularization techniques (L1, L2, Dropout) to prevent overfitting
# 5. Use Early Stopping to optimize training duration
# 6. Perform hyperparameter tuning using Grid Search and Random Search
#
# ## DATASET: Fashion MNIST
# - 70,000 grayscale images (28×28 pixels) of 10 clothing categories
# - Categories: T-shirt, Trouser, Pullover, Dress, Coat, Sandal, Shirt, Sneaker, Bag, Ankle boot
# - Training set: 60,000 images | Test set: 10,000 images
#
# ## INSTRUCTIONS
# - Look for `# TODO:` comments - these are YOUR tasks to complete
# - Each TODO has a **HINT** and **EXPECTED OUTPUT** to guide you
# - Use the verification cells to check your work before moving on
# - Ask questions if you're stuck

# %%
import torch                              # Core tensor operations (like NumPy but with GPU support)
import torch.nn as nn                     # Neural network building blocks (layers, activations)
import torch.optim as optim               # Optimization algorithms (SGD, Adam, etc.)
import torchvision                        # Computer vision datasets and transforms
import torchvision.transforms as transforms  # Image preprocessing utilities
from torch.utils.data import DataLoader, random_split  # Data loading utilities
import numpy as np                        # Numerical computing
import matplotlib.pyplot as plt           # Visualization
# %matplotlib inline
from sklearn.metrics import accuracy_score  # Model evaluation metrics
import random                             # Random number generation
from itertools import product             # Can use for grid search combinations
from torchvision.datasets import FashionMNIST
# Set random seeds for reproducibility (important for debugging!)
torch.manual_seed(42)
random.seed(42)
np.random.seed(42)

print(" All imports successful!")
print(f" PyTorch version: {torch.__version__}")
print(f" CUDA available: {torch.cuda.is_available()}")
# Out:
#  All imports successful!
#  PyTorch version: 2.9.0+cpu
#  CUDA available: False

# %% [markdown]
# ## Section 2: Data Loading & Preprocessing
#
# ### CONCEPT: Data Transforms
# Before feeding images to a neural network, we must convert them to tensors.
#
# `transforms.ToTensor()` does two things:
# 1. Converts PIL Image to Tensor
# 2. Scales pixel values from [0, 255] to [0.0, 1.0]
#
#  **Resources:**
# - [ToTensor](https://pytorch.org/vision/main/generated/torchvision.transforms.ToTensor.html)
# - [Normalize](https://pytorch.org/vision/main/generated/torchvision.transforms.Normalize.html)

# %%
transform = transforms.ToTensor()

# %% [markdown]
# ### TODO 1: Load the Fashion MNIST datasets
#
# **HINT:** Use `torchvision.datasets.FashionMNIST()`
# - Required parameters: `root='./data'`, `train=True/False`, `download=True`, `transform=transform`
#
# **EXPECTED:**
# - `train_dataset` should have 60,000 samples
# - `test_dataset` should have 10,000 samples

# %%
# TODO 1: Load Fashion MNIST datasets
"""
dataset =
print(len(dataset))
train_size = 60000
test_size = 0
train_dataset, test_dataset = random_split(
    dataset, [train_size, test_size]
)
"""
train_dataset = FashionMNIST(root='', train=True, download=True, transform=transforms.ToTensor())
test_dataset = FashionMNIST(root='', train=False, download=True, transform=transforms.ToTensor())
print ("Data succesfully loaded and splited!!")
# Out:
# 100%|██████████| 26.4M/26.4M [00:03<00:00, 8.75MB/s]
# 100%|██████████| 29.5k/29.5k [00:00<00:00, 147kB/s]
# 100%|██████████| 4.42M/4.42M [00:01<00:00, 2.66MB/s]
# 100%|██████████| 5.15k/5.15k [00:00<00:00, 10.4MB/s]
# Data succesfully loaded and splited!!

# %%
# VERIFICATION - Run this cell after completing TODO 1
print(f"Training samples: {len(train_dataset)}")
print(f"Test samples: {len(test_dataset)}")
print(f"Image shape: {train_dataset[0][0].shape}")
# Out:
# Training samples: 60000
# Test samples: 10000
# Image shape: torch.Size([1, 28, 28])

# %% [markdown]
# ### TODO 2: Split the training data into training and validation sets
#
# **WHY?** Validation data helps us monitor for overfitting during training. We never train on validation data - it's our "practice test."

# %%
# TODO 2: Split training data into train and validation sets
train_size = int(0.8 * len(train_dataset))
val_size = len(train_dataset) - train_size
#train_size = int(len(train_dataset)*0,8)
#val_size = int(len(train_dataset)) - train_size

# Uncomment after filling above:
train_dataset, val_dataset = random_split(train_dataset, [train_size, val_size])

print ("Data succesfully splited!!")
# Out:
# Data succesfully splited!!

# %%
# VERIFICATION - Run this cell after completing TODO 2
print(f"Training split: {len(train_dataset)} samples")
print(f"Validation split: {len(val_dataset)} samples")
# Out:
# Training split: 48000 samples
# Validation split: 12000 samples

# %% [markdown]
# ### TODO 3: Create DataLoaders for efficient batching
#
# **WHY DataLoaders?**
# - **Automatic batching:** Groups samples into mini-batches for training
# - **Shuffling:** Randomizes order each epoch to prevent learning data order
#
# **HINT:** `DataLoader(dataset, batch_size=64, shuffle=True/False)`
# - Training: `shuffle=True` (prevents memorizing order)
# - Validation/Test: `shuffle=False` (consistent evaluation)
#
# **Resource:** [DataLoader Documentation](https://pytorch.org/docs/stable/data.html#torch.utils.data.DataLoader)

# %%
# TODO 3: Create DataLoaders

BATCH_SIZE = 64  # Number of samples per gradient update

train_loader = DataLoader(train_dataset, batch_size=64, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=64, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=64, shuffle=False)

print ("Dataloader succesfully created!!!")
# Out:
# Dataloader succesfully created!!!

# %%
class_names = FashionMNIST.classes
data_iter = iter(train_loader)
images, labels = next(data_iter)
images = images.numpy()
fig, axes = plt.subplots(nrows=2, ncols=6, figsize=(12, 5))
axes = axes.ravel()
for i in range(12):
    image = images[i].squeeze()
    axes[i].imshow(image,cmap='gray')
    axes[i].set_title(class_names[labels[i].item()])
    axes[i].axis('off')
plt.tight_layout()
plt.show()

# %%
# VERIFICATION - Run this cell after completing TODO 3
sample_batch, sample_labels = next(iter(train_loader))
print(f"Batch shape: {sample_batch.shape} (expected: [64, 1, 28, 28])")
print(f"Labels shape: {sample_labels.shape} (expected: [64])")
# Out:
# Batch shape: torch.Size([64, 1, 28, 28]) (expected: [64, 1, 28, 28])
# Labels shape: torch.Size([64]) (expected: [64])

# %% [markdown]
# ## Section 3: Neural Network Architecture
#
# ### CONCEPT: Feedforward Neural Network (Multi-Layer Perceptron)
#
# **Architecture (optional architecture):**
# ```
# Input (784) → Hidden1 (256) → Hidden2 (128) → Output (10)
# ```
#
# - **Input:** 28×28 = 784 pixels (flattened image)
# - **Hidden layers:** Learn increasingly abstract features
# - **Output:** 10 neurons (one per clothing category)
#
# **Key Components:**
# - `nn.Linear(in, out)`: Fully connected layer (y = Wx + b)
# - `nn.ReLU()`: Activation function (introduces non-linearity)
# - `nn.Dropout(p)`: Randomly zeros p% of neurons (prevents overfitting)
#
# **Resources:**
# - [nn.Linear](https://pytorch.org/docs/stable/generated/torch.nn.Linear.html)
# - [nn.Dropout](https://pytorch.org/docs/stable/generated/torch.nn.Dropout.html)

# %%
class FashionMNIST_NN(nn.Module):
    """
    A simple feedforward neural network for Fashion MNIST classification.

    Architecture:
        Input (784) → FC1 (256) → ReLU → Dropout → FC2 (128) → ReLU → Dropout → FC3 (10)
        (optional, you can try different architectures)

    Args:
        dropout_rate (float): Probability of dropping neurons (0.0 to 1.0)
    """

    def __init__(self, dropout_rate=0.5):
        super(FashionMNIST_NN, self).__init__()
        # ---------------------------------------------------------------------
        # TODO 4: Define the network layers
        # ---------------------------------------------------------------------
        # HINT: Create three linear layers and dropout
        self.layers = nn.ModuleList([
            nn.Linear(784, 256),
            nn.ReLU(),
            nn.Dropout(dropout_rate),
            nn.Linear(256, 128),
            nn.ReLU(),
            nn.Dropout(dropout_rate),
            nn.Linear(128, 10)
        ])


    def forward(self, x):
        """
        Forward pass: Defines how data flows through the network.

        Args:
            x: Input tensor of shape (batch_size, 1, 28, 28)

        Returns:
            Output tensor of shape (batch_size, 10) - raw scores (logits)
        """
        # ---------------------------------------------------------------------
        # TODO 5: Implement the forward pass
        # ---------------------------------------------------------------------
        # STEP 1: Flatten the input from (batch, 1, 28, 28) to (batch, 784)
        #         HINT: x = x.view(x.size(0), -1)  OR  x = x.flatten(start_dim=1)
        #
        # STEP 2: Pass through layers in order:
        #         fc1 → relu → dropout → fc2 → relu → dropout → fc3
        #
        # IMPORTANT: Do NOT apply softmax here! CrossEntropyLoss expects raw logits.
        #
        # EXPECTED OUTPUT SHAPE: (batch_size, 10)
        # ---------------------------------------------------------------------

        x = x.view(x.size(0), -1)  # flatten

        for layer in self.layers:
            x = layer (x)

        return x

print ("Model succesfully created!!!")
        # return out
# Out:
# Model succesfully created!!!

# %%
# 🔍 VERIFICATION - Run this cell after completing TODOs 4 & 5
test_model = FashionMNIST_NN(dropout_rate=0.5)
test_input = torch.randn(64, 1, 28, 28)  # Fake batch
test_output = test_model(test_input)
print(f"Model output shape: {test_output.shape}")
print(f"Total parameters: {sum(p.numel() for p in test_model.parameters()):,}")
# Out:
# Model output shape: torch.Size([64, 10])
# Total parameters: 235,146

# %% [markdown]
# ## Section 4: Weight Initialization
#
# ### CONCEPT: Why Initialize Weights Carefully?
#
# Poor initialization can cause:
# - **Vanishing gradients:** Signals shrink to zero → no learning
# - **Exploding gradients:** Signals grow huge → unstable training
#
# **Common Methods:**
# - **Xavier (Glorot):** Best for tanh/sigmoid activations
# - **Kaiming (He):** Best for ReLU activations ← We use ReLU, so this is preferred!
#
# **Resource:** [PyTorch nn.init](https://pytorch.org/docs/stable/nn.init.html)

# %%
def initialize_weights(model, method='kaiming'):
    """
    Initialize the weights of a neural network.

    Args:
        model: The neural network model
        method: 'xavier' or 'kaiming' (default: 'kaiming' for ReLU networks)
    """
    for layer in model.modules():
        if isinstance(layer, nn.Linear):
            if method == 'xavier':
                nn.init.xavier_uniform_(layer.weight)
            elif method == 'kaiming':
                nn.init.kaiming_uniform_(layer.weight, nonlinearity='relu')
            # Initialize biases to zero
            if layer.bias is not None:
                nn.init.zeros_(layer.bias)

    print(f"Weights initialized using {method} method")

model = FashionMNIST_NN()
initialize_weights(model)
# Out:
# Weights initialized using kaiming method

# %%
print("START")
initialize_weights(model, "kaiming")
print("END")
# Out:
# START
# Weights initialized using kaiming method
# END

# %%
initialize_weights(model, "kaiming")
# Out:
# Weights initialized using kaiming method

# %% [markdown]
# ## Section 5: Early Stopping (Provided - Study This Code)
#
# ### CONCEPT: Early Stopping
#
# **Problem:** Training too long leads to overfitting.
#
# **Solution:** Monitor validation loss and stop when it stops improving.
#
# **How it works:**
# 1. Track the best validation loss seen so far
# 2. If validation loss doesn't improve for `patience` epochs, stop training
# 3. Save the best model weights to restore later
#
# This is a form of regularization - it prevents the model from overfitting.

# %%
class EarlyStopping:
    """
    Stops training when validation loss stops improving.

    Args:
        patience (int): How many epochs to wait for improvement
        delta (float): Minimum change to qualify as an improvement
    """

    def __init__(self, patience=5, delta=0):
        self.patience = patience
        self.counter = 0
        self.best_score = None
        self.early_stop = False
        self.delta = delta
        self.best_val_loss = float('inf')

    def __call__(self, val_loss, model):
        score = -val_loss  # We want to maximize score (minimize loss)

        if self.best_score is None:
            # First epoch - save as best
            self.best_score = score
            self.save_checkpoint(val_loss, model)
        elif score < self.best_score + self.delta:
            # No improvement
            self.counter += 1
            print(f"EarlyStopping counter: {self.counter}/{self.patience}")
            if self.counter >= self.patience:
                self.early_stop = True
        else:
            # Improvement! Reset counter
            self.best_score = score
            self.save_checkpoint(val_loss, model)
            self.counter = 0

    def save_checkpoint(self, val_loss, model):
        """Saves model when validation loss decreases."""
        self.best_val_loss = val_loss
        torch.save(model.state_dict(), 'best_model_checkpoint.pth')
        print(f"Checkpoint saved! (val_loss: {val_loss:.4f})")

print ("Early Stopping class succesfully created!!!")
# Out:
# Early Stopping class succesfully created!!!

# %% [markdown]
# ## Section 6: Training Function
#
# ### CONCEPT: The Training Loop
#
# Every epoch consists of:
#
# **1. TRAINING PHASE** (`model.train()`):
#    - Forward pass: Compute predictions
#    - Loss calculation: Measure how wrong we are
#    - Backward pass: Compute gradients
#    - Optimization: Update weights
#
# **2. VALIDATION PHASE** (`model.eval()`):
#    - Forward pass only (no gradient computation)
#    - Measure validation loss to monitor overfitting
#
# ### CONCEPT: Regularization
# - **L1 (Lasso):** Encourages sparse weights (many zeros) → Feature selection
# - **L2 (Ridge):** Encourages small weights → Prevents any single feature from dominating
# - **Dropout:** Randomly "turns off" neurons → Forces redundancy in learned features

# %%
def train_model(l1_lambda=0, l2_lambda=0.01, dropout_rate=0.5, weight_init='kaiming', lr=0.01):
    """
    Train a Fashion MNIST classifier with regularization.

    Args:
        l1_lambda: L1 regularization strength (0 = no L1)
        l2_lambda: L2 regularization strength (0 = no L2)
        dropout_rate: Dropout probability (0 = no dropout)
        weight_init: Weight initialization method ('xavier' or 'kaiming')
        lr: Learning rate for optimizer

    Returns:
        model: Trained model
        train_losses: List of training losses per epoch
        val_losses: List of validation losses per epoch
    """

    # =========================================================================
    # STEP 1: Create and initialize the model
    # =========================================================================
    # TODO 6: Create the model with the specified dropout rate
    # =========================================================================

    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

    model = FashionMNIST_NN(dropout_rate=dropout_rate).to(device)
    model = model.to(device)

    initialize_weights(model, weight_init)  # Uncomment after creating model
    #print("Model initialized")
    # =========================================================================
    # STEP 2: Define the optimizer
    # =========================================================================
    # TODO 7: Create an SGD optimizer with L2 regularization
    #
    # WHY SGD? It's the foundational optimizer - understanding it helps you
    # appreciate more advanced optimizers like Adam.
    #
    # Check weight decay parameter of SGD for L2 regularization. Set weight_decay=l2_lambda, if u want to use L2 regularization
    #
    # HINT:https://pytorch.org/docs/stable/generated/torch.optim.SGD.html
    # =========================================================================
    optimizer = torch.optim.SGD(model.parameters(), lr=lr, weight_decay=l2_lambda)







    # =========================================================================
    # STEP 3: Define the loss function
    # =========================================================================
    # TODO 8: Create a CrossEntropyLoss criterion
    #
    # WHY CrossEntropyLoss for classification?
    # - It combines LogSoftmax + NLLLoss in one optimized operation. If you want to use Softmax explicitly, you should use nn.NLLLoss after applying nn.LogSoftmax.
    # However, you do not need to do this here since we are using CrossEntropyLoss. Read the documentation below.
    # - Perfect for multi-class classification (choosing 1 of N classes)
    # - Input: Raw logits (NOT softmax probabilities!)
    # - Target: Class indices (0-9 for Fashion MNIST)
    #
    # HINT: https://pytorch.org/docs/stable/generated/torch.nn.CrossEntropyLoss.html
    # =========================================================================

    criterion = nn.CrossEntropyLoss()

    # Early stopping to prevent overfitting
    early_stopping = EarlyStopping(patience=20)

    # =========================================================================
    # STEP 4: Training loop
    # =========================================================================
    num_epochs = 100  # Maximum epochs (early stopping may end sooner)
    train_losses = []
    val_losses = []

    print("=" * 60)
    print("TRAINING STARTED")
    print("=" * 60)

    for epoch in range(num_epochs):
        # =====================================================================
        # TRAINING PHASE
        # =====================================================================
        model.train()  # Enable dropout and batch norm training behavior
        train_loss = 0.0

        for batch_idx, (inputs, labels) in enumerate(train_loader):
            # -----------------------------------------------------------------
            # TODO 9: Implement the training step
            inputs = inputs.to(device)
            labels = labels.to(device)

            # -----------------------------------------------------------------
            # STEP A: Forward pass - get model predictions
            outputs = model(inputs)
            # STEP B: Compute loss
            loss = criterion(outputs, labels)
            # STEP C: Add L1 regularization (if l1_lambda > 0) (optional)
            #         L1 norm = sum of absolute values of all parameters
            if l1_lambda > 0:
                l1_norm = torch.tensor(0., device=device)
                for p in model.parameters():
                    l1_norm += p.abs().sum()
                loss = loss + l1_lambda * l1_norm
            # STEP D: Zero gradients (WHY? Gradients accumulate by default!)
            optimizer.zero_grad()
            # STEP E: Backward pass - compute gradients
            loss.backward()
            # STEP F: Update weights
            optimizer.step()
            # -----------------------------------------------------------------

            train_loss += loss.item()  # Uncomment after implementing

        # =====================================================================
        # VALIDATION PHASE
        # =====================================================================
        model.eval()  # Disable dropout for evaluation
        val_loss = 0.0

        with torch.no_grad():  # Disable gradient computation (saves memory)
            for inputs, labels in val_loader:
              inputs = inputs.to(device)
              labels = labels.to(device)

              outputs = model(inputs)
              loss = criterion(outputs, labels)
                # -------------------------------------------------------------
                # TODO 10: Implement validation step
                # -------------------------------------------------------------
                # Only forward pass needed (no backward, no optimizer))
                # -------------------------------------------------------------

            val_loss += loss.item()  # Uncomment after implementing

        # Calculate average losses
        avg_train_loss = train_loss / len(train_loader)
        avg_val_loss   = val_loss   / len(val_loader)

        train_losses.append(avg_train_loss)
        val_losses.append(avg_val_loss)

        # Print progress
        print(f"Epoch [{epoch+1:2d}/{num_epochs}] | "
              f"Train Loss: {avg_train_loss:.4f} | "
              f"Val Loss: {avg_val_loss:.4f}")

        # Check early stopping
        early_stopping(avg_val_loss, model)
        if early_stopping.early_stop:
            print(f"Early stopping triggered at epoch {epoch+1}")
            break

    print("=" * 60)
    print("TRAINING COMPLETED")
    print(f"Best validation loss: {early_stopping.best_val_loss:.4f}")
    print("=" * 60)

    # Load best model weights
    model.load_state_dict(torch.load('best_model_checkpoint.pth'))

    return model, train_losses, val_losses

print("FUNCTION CALL START")
model, train_losses, val_losses = train_model()
print("FUNCTION CALL END")
# Out:
# FUNCTION CALL START
# Weights initialized using kaiming method
# ============================================================
# TRAINING STARTED
# ============================================================
# Epoch [ 1/100] | Train Loss: 1.3129 | Val Loss: 0.0030
# Checkpoint saved! (val_loss: 0.0030)
# Epoch [ 2/100] | Train Loss: 0.8962 | Val Loss: 0.0023
# Checkpoint saved! (val_loss: 0.0023)
# Epoch [ 3/100] | Train Loss: 0.7864 | Val Loss: 0.0021
# Checkpoint saved! (val_loss: 0.0021)
# Epoch [ 4/100] | Train Loss: 0.7233 | Val Loss: 0.0018
# Checkpoint saved! (val_loss: 0.0018)
# Epoch [ 5/100] | Train Loss: 0.6917 | Val Loss: 0.0018
# Checkpoint saved! (val_loss: 0.0018)
# Epoch [ 6/100] | Train Loss: 0.6623 | Val Loss: 0.0017
# Checkpoint saved! (val_loss: 0.0017)
# Epoch [ 7/100] | Train Loss: 0.6425 | Val Loss: 0.0017
# Checkpoint saved! (val_loss: 0.0017)
# Epoch [ 8/100] | Train Loss: 0.6208 | Val Loss: 0.0015
# Checkpoint saved! (val_loss: 0.0015)
# Epoch [ 9/100] | Train Loss: 0.6147 | Val Loss: 0.0015
# EarlyStopping counter: 1/20
# Epoch [10/100] | Train Loss: 0.5985 | Val Loss: 0.0014
# Checkpoint saved! (val_loss: 0.0014)
# Epoch [11/100] | Train Loss: 0.5889 | Val Loss: 0.0015
# EarlyStopping counter: 1/20
# Epoch [12/100] | Train Loss: 0.5845 | Val Loss: 0.0014
# Checkpoint saved! (val_loss: 0.0014)
# Epoch [13/100] | Train Loss: 0.5775 | Val Loss: 0.0014
# Checkpoint saved! (val_loss: 0.0014)
# Epoch [14/100] | Train Loss: 0.5707 | Val Loss: 0.0014
# EarlyStopping counter: 1/20
# Epoch [15/100] | Train Loss: 0.5641 | Val Loss: 0.0014
# EarlyStopping counter: 2/20
# Epoch [16/100] | Train Loss: 0.5595 | Val Loss: 0.0015
# EarlyStopping counter: 3/20
# Epoch [17/100] | Train Loss: 0.5557 | Val Loss: 0.0014
# Checkpoint saved! (val_loss: 0.0014)
# Epoch [18/100] | Train Loss: 0.5540 | Val Loss: 0.0014
# Checkpoint saved! (val_loss: 0.0014)
# Epoch [19/100] | Train Loss: 0.5510 | Val Loss: 0.0014
# EarlyStopping counter: 1/20
# Epoch [20/100] | Train Loss: 0.5497 | Val Loss: 0.0013
# Checkpoint saved! (val_loss: 0.0013)
# Epoch [21/100] | Train Loss: 0.5464 | Val Loss: 0.0014
# EarlyStopping counter: 1/20
# Epoch [22/100] | Train Loss: 0.5446 | Val Loss: 0.0014
# EarlyStopping counter: 2/20
# Epoch [23/100] | Train Loss: 0.5402 | Val Loss: 0.0014
# EarlyStopping counter: 3/20
# Epoch [24/100] | Train Loss: 0.5405 | Val Loss: 0.0013
# Checkpoint saved! (val_loss: 0.0013)
# Epoch [25/100] | Train Loss: 0.5399 | Val Loss: 0.0014
# EarlyStopping counter: 1/20
# Epoch [26/100] | Train Loss: 0.5346 | Val Loss: 0.0013
# EarlyStopping counter: 2/20
# Epoch [27/100] | Train Loss: 0.5320 | Val Loss: 0.0013
# Checkpoint saved! (val_loss: 0.0013)
# Epoch [28/100] | Train Loss: 0.5307 | Val Loss: 0.0013
# Checkpoint saved! (val_loss: 0.0013)
# Epoch [29/100] | Train Loss: 0.5277 | Val Loss: 0.0013
# Checkpoint saved! (val_loss: 0.0013)
# Epoch [30/100] | Train Loss: 0.5306 | Val Loss: 0.0014
# EarlyStopping counter: 1/20
# Epoch [31/100] | Train Loss: 0.5268 | Val Loss: 0.0013
# EarlyStopping counter: 2/20
# Epoch [32/100] | Train Loss: 0.5272 | Val Loss: 0.0013
# EarlyStopping counter: 3/20
# Epoch [33/100] | Train Loss: 0.5220 | Val Loss: 0.0013
# Checkpoint saved! (val_loss: 0.0013)
# Epoch [34/100] | Train Loss: 0.5228 | Val Loss: 0.0012
# Checkpoint saved! (val_loss: 0.0012)
# Epoch [35/100] | Train Loss: 0.5251 | Val Loss: 0.0012
# Checkpoint saved! (val_loss: 0.0012)
# Epoch [36/100] | Train Loss: 0.5230 | Val Loss: 0.0013
# EarlyStopping counter: 1/20
# Epoch [37/100] | Train Loss: 0.5225 | Val Loss: 0.0013
# EarlyStopping counter: 2/20
# Epoch [38/100] | Train Loss: 0.5191 | Val Loss: 0.0013
# EarlyStopping counter: 3/20
# Epoch [39/100] | Train Loss: 0.5200 | Val Loss: 0.0013
# EarlyStopping counter: 4/20
# Epoch [40/100] | Train Loss: 0.5179 | Val Loss: 0.0013
# EarlyStopping counter: 5/20
# Epoch [41/100] | Train Loss: 0.5191 | Val Loss: 0.0012
# Checkpoint saved! (val_loss: 0.0012)
# Epoch [42/100] | Train Loss: 0.5170 | Val Loss: 0.0013
# EarlyStopping counter: 1/20
# Epoch [43/100] | Train Loss: 0.5166 | Val Loss: 0.0013
# EarlyStopping counter: 2/20
# Epoch [44/100] | Train Loss: 0.5161 | Val Loss: 0.0013
# EarlyStopping counter: 3/20
# Epoch [45/100] | Train Loss: 0.5144 | Val Loss: 0.0013
# EarlyStopping counter: 4/20
# Epoch [46/100] | Train Loss: 0.5152 | Val Loss: 0.0013
# EarlyStopping counter: 5/20
# Epoch [47/100] | Train Loss: 0.5152 | Val Loss: 0.0012
# Checkpoint saved! (val_loss: 0.0012)
# Epoch [48/100] | Train Loss: 0.5136 | Val Loss: 0.0013
# EarlyStopping counter: 1/20
# Epoch [49/100] | Train Loss: 0.5155 | Val Loss: 0.0012
# EarlyStopping counter: 2/20
# Epoch [50/100] | Train Loss: 0.5144 | Val Loss: 0.0013
# EarlyStopping counter: 3/20
# Epoch [51/100] | Train Loss: 0.5118 | Val Loss: 0.0012
# EarlyStopping counter: 4/20
# Epoch [52/100] | Train Loss: 0.5140 | Val Loss: 0.0012
# EarlyStopping counter: 5/20
# Epoch [53/100] | Train Loss: 0.5123 | Val Loss: 0.0011
# Checkpoint saved! (val_loss: 0.0011)
# Epoch [54/100] | Train Loss: 0.5132 | Val Loss: 0.0012
# EarlyStopping counter: 1/20
# Epoch [55/100] | Train Loss: 0.5083 | Val Loss: 0.0012
# EarlyStopping counter: 2/20
# Epoch [56/100] | Train Loss: 0.5137 | Val Loss: 0.0012
# EarlyStopping counter: 3/20
# Epoch [57/100] | Train Loss: 0.5086 | Val Loss: 0.0013
# EarlyStopping counter: 4/20
# Epoch [58/100] | Train Loss: 0.5109 | Val Loss: 0.0012
# EarlyStopping counter: 5/20
# Epoch [59/100] | Train Loss: 0.5092 | Val Loss: 0.0012
# EarlyStopping counter: 6/20
# Epoch [60/100] | Train Loss: 0.5113 | Val Loss: 0.0012
# EarlyStopping counter: 7/20
# Epoch [61/100] | Train Loss: 0.5096 | Val Loss: 0.0013
# EarlyStopping counter: 8/20
# Epoch [62/100] | Train Loss: 0.5086 | Val Loss: 0.0012
# EarlyStopping counter: 9/20
# Epoch [63/100] | Train Loss: 0.5073 | Val Loss: 0.0012
# EarlyStopping counter: 10/20
# Epoch [64/100] | Train Loss: 0.5067 | Val Loss: 0.0012
# EarlyStopping counter: 11/20
# Epoch [65/100] | Train Loss: 0.5066 | Val Loss: 0.0013
# EarlyStopping counter: 12/20
# Epoch [66/100] | Train Loss: 0.5076 | Val Loss: 0.0012
# EarlyStopping counter: 13/20
# Epoch [67/100] | Train Loss: 0.5070 | Val Loss: 0.0012
# EarlyStopping counter: 14/20
# Epoch [68/100] | Train Loss: 0.5083 | Val Loss: 0.0012
# EarlyStopping counter: 15/20
# Epoch [69/100] | Train Loss: 0.5102 | Val Loss: 0.0013
# EarlyStopping counter: 16/20
# Epoch [70/100] | Train Loss: 0.5057 | Val Loss: 0.0012
# EarlyStopping counter: 17/20
# Epoch [71/100] | Train Loss: 0.5049 | Val Loss: 0.0012
# EarlyStopping counter: 18/20
# Epoch [72/100] | Train Loss: 0.5063 | Val Loss: 0.0012
# EarlyStopping counter: 19/20
# Epoch [73/100] | Train Loss: 0.5046 | Val Loss: 0.0012
# EarlyStopping counter: 20/20
# Early stopping triggered at epoch 73
# ============================================================
# TRAINING COMPLETED
# Best validation loss: 0.0011
# ============================================================
# FUNCTION CALL END

# %% [markdown]
# ## Section 7: Testing Function

# %%
def test_model(model):
    """
    Evaluate the model on the test set.

    Args:
        model: Trained model to eva luate

    Returns:
        test_acc: Test accuracy (0.0 to 1.0)
    """
    model.eval()  # Set to evaluation mode
    all_preds = []
    all_labels = []

    with torch.no_grad():
        for inputs, labels in test_loader:
            # -----------------------------------------------------------------
            # TODO 11: Implement test prediction
            # -----------------------------------------------------------------
            # STEP A: Forward pass
            outputs = model(inputs)
            #
            # STEP B: Get predicted class (index of maximum logit)
            preds = outputs.argmax(dim=1)
            #         WHY argmax? Each output neuron gives a score for its class.
            #         The predicted class is the one with the highest score.
            #         Check argmax documentation if needed: https://docs.pytorch.org/docs/stable/generated/torch.argmax.html#torch.argmax
            # -----------------------------------------------------------------

            all_preds.append(preds)    # Uncomment after implementing
            all_labels.append(labels)  # Uncomment after implementing

    # Concatenate all batches
    all_preds = torch.cat(all_preds)
    all_labels = torch.cat(all_labels)

    # Calculate accuracy
    # Resource: https://scikit-learn.org/stable/modules/generated/sklearn.metrics.accuracy_score.html
    test_acc = accuracy_score(all_labels.numpy(), all_preds.numpy())

    print(f"TEST ACCURACY: {test_acc:.4f} ({test_acc*100:.2f}%)")

    return test_acc

print("=" * 50)
print("TEST FUNCTION CALL START")

test_acc = test_model(model)

print("TEST FUNCTION CALL END")
print("=" * 50)
# Out:
# ==================================================
# TEST FUNCTION CALL START
# TEST ACCURACY: 0.8390 (83.90%)
# TEST FUNCTION CALL END
# ==================================================

# %% [markdown]
# ## Section 8: Visualization

# %%
def plot_losses(train_losses, val_losses):
    """
    Plot training and validation losses over epochs.

    A healthy training curve shows:
    - Both losses decreasing initially
    - Validation loss eventually plateauing or slightly increasing (overfitting starts)
    - Gap between train and val loss indicates overfitting severity
    """
    # -------------------------------------------------------------------------
    # TODO 12: Implement loss plotting
    # -------------------------------------------------------------------------
    #   # Set figure size
    plt.figure(figsize=(10, 6))
    #   # Plot training and validation losses
    plt.plot(train_losses, label="Training Loss", linewidth=2)
    plt.plot(val_losses, label="Validation Loss", linewidth=2)
    #   # Set labels and title
    plt.xlabel("Epoch")
    plt.ylabel("Loss")
    plt.title("Training vs Validation Loss")
    #   # Put xlabel, ylabel, title, legend, grid
    plt.legend()
    plt.show()
print("PLOT START")
plot_losses(train_losses, val_losses)
print("PLOT END")
# Out:
# PLOT START
# PLOT END

# %%
def plot_losses(val_losses):
    plt.figure(figsize=(10, 6))
    plt.plot(val_losses, label="Validation Loss", linewidth=2)
    plt.xlabel("Epoch")
    plt.ylabel("Loss")
    plt.title("Validation Loss")
    plt.legend()
    plt.show()
print("PLOT START")
plot_losses(val_losses)
print("PLOT END")
# Out:
# PLOT START
# PLOT END

# %% [markdown]
# ## Section 9: Run the Experiment
#
# # Ablation Study Instructions
#
# Here you can run your ablation studies manually. What we recommend is that you change the hyperparameters below and also the number of weights in the model. You might also adjust the early stopping patience parameter. You can have a few objectives:
#
# - Get ≈90%-95% test accuracy score
# - Try to overfit and observe the validation and training curves
# - Try to underfit and observe it
# - Observe how different hyperparameters actually affect the training (for example, you can set the learning rate to 100, set lambda_1 to 1, or set dropout to 0.9 and observe what kind of different scenarios you encounter)
#
# In order to do these objectives, you should understand the code and change the correct parameters. If you are able to apply these different settings and accomplish these scenarios, that is a good sign.

# %%
l1_lambda = 0.0001      # L1 regularization strength
l2_lambda = 0.001       # L2 regularization strength (instead of implementing this by hand,
                       # you can also play with SGD weight_decay parameter)
dropout_rate = 0.3     # Dropout probability (try: 0.0, 0.3, 0.5, 0.7)
weight_init = 'kaiming'  # Weight initialization ('xavier' or 'kaiming')
learning_rate = 0.001   # Learning rate (ou can try 10, 1000, crazy learning rates and fail
                       # to learn)

print("\n" + "=" * 60)
print("HYPERPARAMETER CONFIGURATION")
print("=" * 60)
print(f"   L1 Lambda:      {l1_lambda}")
print(f"   L2 Lambda:      {l2_lambda}")
print(f"   Dropout Rate:   {dropout_rate}")
print(f"   Weight Init:    {weight_init}")
print(f"   Learning Rate:  {learning_rate}")
print("=" * 60 + "\n")
# Out:
# ============================================================
# HYPERPARAMETER CONFIGURATION
# ============================================================
#    L1 Lambda:      0.0001
#    L2 Lambda:      0.001
#    Dropout Rate:   0.3
#    Weight Init:    kaiming
#    Learning Rate:  0.001
# ============================================================

# %%
# Train the model
model, train_losses, val_losses = train_model(
    l1_lambda=l1_lambda,
    l2_lambda=l2_lambda,
    dropout_rate=dropout_rate,
    weight_init=weight_init,
    lr=learning_rate
)
# Out:
# Weights initialized using kaiming method
# ============================================================
# TRAINING STARTED
# ============================================================
# Epoch [ 1/100] | Train Loss: 3.0711 | Val Loss: 0.0064
# Checkpoint saved! (val_loss: 0.0064)
# Epoch [ 2/100] | Train Loss: 2.5439 | Val Loss: 0.0047
# Checkpoint saved! (val_loss: 0.0047)
# Epoch [ 3/100] | Train Loss: 2.3360 | Val Loss: 0.0039
# Checkpoint saved! (val_loss: 0.0039)
# Epoch [ 4/100] | Train Loss: 2.2173 | Val Loss: 0.0034
# Checkpoint saved! (val_loss: 0.0034)
# Epoch [ 5/100] | Train Loss: 2.1384 | Val Loss: 0.0032
# Checkpoint saved! (val_loss: 0.0032)
# Epoch [ 6/100] | Train Loss: 2.0814 | Val Loss: 0.0030
# Checkpoint saved! (val_loss: 0.0030)
# Epoch [ 7/100] | Train Loss: 2.0337 | Val Loss: 0.0028
# Checkpoint saved! (val_loss: 0.0028)
# Epoch [ 8/100] | Train Loss: 1.9953 | Val Loss: 0.0026
# Checkpoint saved! (val_loss: 0.0026)
# Epoch [ 9/100] | Train Loss: 1.9703 | Val Loss: 0.0025
# Checkpoint saved! (val_loss: 0.0025)
# Epoch [10/100] | Train Loss: 1.9438 | Val Loss: 0.0024
# Checkpoint saved! (val_loss: 0.0024)
# Epoch [11/100] | Train Loss: 1.9172 | Val Loss: 0.0023
# Checkpoint saved! (val_loss: 0.0023)
# Epoch [12/100] | Train Loss: 1.8949 | Val Loss: 0.0022
# Checkpoint saved! (val_loss: 0.0022)
# Epoch [13/100] | Train Loss: 1.8763 | Val Loss: 0.0021
# Checkpoint saved! (val_loss: 0.0021)
# Epoch [14/100] | Train Loss: 1.8592 | Val Loss: 0.0020
# Checkpoint saved! (val_loss: 0.0020)
# Epoch [15/100] | Train Loss: 1.8461 | Val Loss: 0.0020
# Checkpoint saved! (val_loss: 0.0020)
# Epoch [16/100] | Train Loss: 1.8271 | Val Loss: 0.0019
# Checkpoint saved! (val_loss: 0.0019)
# Epoch [17/100] | Train Loss: 1.8154 | Val Loss: 0.0019
# Checkpoint saved! (val_loss: 0.0019)
# Epoch [18/100] | Train Loss: 1.7991 | Val Loss: 0.0018
# Checkpoint saved! (val_loss: 0.0018)
# Epoch [19/100] | Train Loss: 1.7878 | Val Loss: 0.0018
# EarlyStopping counter: 1/20
# Epoch [20/100] | Train Loss: 1.7796 | Val Loss: 0.0018
# Checkpoint saved! (val_loss: 0.0018)
# Epoch [21/100] | Train Loss: 1.7684 | Val Loss: 0.0017
# Checkpoint saved! (val_loss: 0.0017)
# Epoch [22/100] | Train Loss: 1.7551 | Val Loss: 0.0017
# Checkpoint saved! (val_loss: 0.0017)
# Epoch [23/100] | Train Loss: 1.7477 | Val Loss: 0.0017
# Checkpoint saved! (val_loss: 0.0017)
# Epoch [24/100] | Train Loss: 1.7341 | Val Loss: 0.0016
# Checkpoint saved! (val_loss: 0.0016)
# Epoch [25/100] | Train Loss: 1.7282 | Val Loss: 0.0016
# Checkpoint saved! (val_loss: 0.0016)
# Epoch [26/100] | Train Loss: 1.7199 | Val Loss: 0.0016
# EarlyStopping counter: 1/20
# Epoch [27/100] | Train Loss: 1.7085 | Val Loss: 0.0016
# Checkpoint saved! (val_loss: 0.0016)
# Epoch [28/100] | Train Loss: 1.7017 | Val Loss: 0.0016
# Checkpoint saved! (val_loss: 0.0016)
# Epoch [29/100] | Train Loss: 1.6897 | Val Loss: 0.0016
# EarlyStopping counter: 1/20
# Epoch [30/100] | Train Loss: 1.6842 | Val Loss: 0.0015
# Checkpoint saved! (val_loss: 0.0015)
# Epoch [31/100] | Train Loss: 1.6801 | Val Loss: 0.0015
# Checkpoint saved! (val_loss: 0.0015)
# Epoch [32/100] | Train Loss: 1.6711 | Val Loss: 0.0015
# Checkpoint saved! (val_loss: 0.0015)
# Epoch [33/100] | Train Loss: 1.6641 | Val Loss: 0.0015
# Checkpoint saved! (val_loss: 0.0015)
# Epoch [34/100] | Train Loss: 1.6555 | Val Loss: 0.0015
# EarlyStopping counter: 1/20
# Epoch [35/100] | Train Loss: 1.6510 | Val Loss: 0.0015
# Checkpoint saved! (val_loss: 0.0015)
# Epoch [36/100] | Train Loss: 1.6467 | Val Loss: 0.0014
# Checkpoint saved! (val_loss: 0.0014)
# Epoch [37/100] | Train Loss: 1.6360 | Val Loss: 0.0014
# Checkpoint saved! (val_loss: 0.0014)
# Epoch [38/100] | Train Loss: 1.6291 | Val Loss: 0.0014
# EarlyStopping counter: 1/20
# Epoch [39/100] | Train Loss: 1.6259 | Val Loss: 0.0014
# Checkpoint saved! (val_loss: 0.0014)
# Epoch [40/100] | Train Loss: 1.6210 | Val Loss: 0.0014
# Checkpoint saved! (val_loss: 0.0014)
# Epoch [41/100] | Train Loss: 1.6184 | Val Loss: 0.0014
# Checkpoint saved! (val_loss: 0.0014)
# Epoch [42/100] | Train Loss: 1.6093 | Val Loss: 0.0014
# Checkpoint saved! (val_loss: 0.0014)
# Epoch [43/100] | Train Loss: 1.6039 | Val Loss: 0.0014
# EarlyStopping counter: 1/20
# Epoch [44/100] | Train Loss: 1.5989 | Val Loss: 0.0014
# Checkpoint saved! (val_loss: 0.0014)
# Epoch [45/100] | Train Loss: 1.5931 | Val Loss: 0.0014
# EarlyStopping counter: 1/20
# Epoch [46/100] | Train Loss: 1.5859 | Val Loss: 0.0014
# EarlyStopping counter: 2/20
# Epoch [47/100] | Train Loss: 1.5807 | Val Loss: 0.0014
# EarlyStopping counter: 3/20
# Epoch [48/100] | Train Loss: 1.5765 | Val Loss: 0.0013
# Checkpoint saved! (val_loss: 0.0013)
# Epoch [49/100] | Train Loss: 1.5748 | Val Loss: 0.0013
# EarlyStopping counter: 1/20
# Epoch [50/100] | Train Loss: 1.5706 | Val Loss: 0.0013
# Checkpoint saved! (val_loss: 0.0013)
# Epoch [51/100] | Train Loss: 1.5638 | Val Loss: 0.0013
# Checkpoint saved! (val_loss: 0.0013)
# Epoch [52/100] | Train Loss: 1.5563 | Val Loss: 0.0013
# EarlyStopping counter: 1/20
# Epoch [53/100] | Train Loss: 1.5523 | Val Loss: 0.0013
# EarlyStopping counter: 2/20
# Epoch [54/100] | Train Loss: 1.5516 | Val Loss: 0.0013
# EarlyStopping counter: 3/20
# Epoch [55/100] | Train Loss: 1.5424 | Val Loss: 0.0013
# EarlyStopping counter: 4/20
# Epoch [56/100] | Train Loss: 1.5435 | Val Loss: 0.0013
# Checkpoint saved! (val_loss: 0.0013)
# Epoch [57/100] | Train Loss: 1.5356 | Val Loss: 0.0013
# Checkpoint saved! (val_loss: 0.0013)
# Epoch [58/100] | Train Loss: 1.5343 | Val Loss: 0.0013
# Checkpoint saved! (val_loss: 0.0013)
# Epoch [59/100] | Train Loss: 1.5245 | Val Loss: 0.0013
# EarlyStopping counter: 1/20
# Epoch [60/100] | Train Loss: 1.5230 | Val Loss: 0.0013
# EarlyStopping counter: 2/20
# Epoch [61/100] | Train Loss: 1.5173 | Val Loss: 0.0013
# Checkpoint saved! (val_loss: 0.0013)
# Epoch [62/100] | Train Loss: 1.5175 | Val Loss: 0.0013
# Checkpoint saved! (val_loss: 0.0013)
# Epoch [63/100] | Train Loss: 1.5115 | Val Loss: 0.0013
# Checkpoint saved! (val_loss: 0.0013)
# Epoch [64/100] | Train Loss: 1.5056 | Val Loss: 0.0013
# Checkpoint saved! (val_loss: 0.0013)
# Epoch [65/100] | Train Loss: 1.5001 | Val Loss: 0.0013
# EarlyStopping counter: 1/20
# Epoch [66/100] | Train Loss: 1.4965 | Val Loss: 0.0013
# EarlyStopping counter: 2/20
# Epoch [67/100] | Train Loss: 1.4948 | Val Loss: 0.0013
# EarlyStopping counter: 3/20
# Epoch [68/100] | Train Loss: 1.4893 | Val Loss: 0.0012
# Checkpoint saved! (val_loss: 0.0012)
# Epoch [69/100] | Train Loss: 1.4884 | Val Loss: 0.0013
# EarlyStopping counter: 1/20
# Epoch [70/100] | Train Loss: 1.4817 | Val Loss: 0.0012
# EarlyStopping counter: 2/20
# Epoch [71/100] | Train Loss: 1.4806 | Val Loss: 0.0012
# EarlyStopping counter: 3/20
# Epoch [72/100] | Train Loss: 1.4728 | Val Loss: 0.0012
# Checkpoint saved! (val_loss: 0.0012)
# Epoch [73/100] | Train Loss: 1.4710 | Val Loss: 0.0012
# EarlyStopping counter: 1/20
# Epoch [74/100] | Train Loss: 1.4665 | Val Loss: 0.0012
# Checkpoint saved! (val_loss: 0.0012)
# Epoch [75/100] | Train Loss: 1.4668 | Val Loss: 0.0012
# EarlyStopping counter: 1/20
# Epoch [76/100] | Train Loss: 1.4586 | Val Loss: 0.0012
# Checkpoint saved! (val_loss: 0.0012)
# Epoch [77/100] | Train Loss: 1.4547 | Val Loss: 0.0012
# EarlyStopping counter: 1/20
# Epoch [78/100] | Train Loss: 1.4519 | Val Loss: 0.0012
# Checkpoint saved! (val_loss: 0.0012)
# Epoch [79/100] | Train Loss: 1.4479 | Val Loss: 0.0012
# EarlyStopping counter: 1/20
# Epoch [80/100] | Train Loss: 1.4448 | Val Loss: 0.0012
# EarlyStopping counter: 2/20
# Epoch [81/100] | Train Loss: 1.4427 | Val Loss: 0.0012
# Checkpoint saved! (val_loss: 0.0012)
# Epoch [82/100] | Train Loss: 1.4380 | Val Loss: 0.0012
# Checkpoint saved! (val_loss: 0.0012)
# Epoch [83/100] | Train Loss: 1.4354 | Val Loss: 0.0011
# Checkpoint saved! (val_loss: 0.0011)
# Epoch [84/100] | Train Loss: 1.4328 | Val Loss: 0.0012
# EarlyStopping counter: 1/20
# Epoch [85/100] | Train Loss: 1.4298 | Val Loss: 0.0012
# EarlyStopping counter: 2/20
# Epoch [86/100] | Train Loss: 1.4265 | Val Loss: 0.0012
# EarlyStopping counter: 3/20
# Epoch [87/100] | Train Loss: 1.4226 | Val Loss: 0.0011
# EarlyStopping counter: 4/20
# Epoch [88/100] | Train Loss: 1.4205 | Val Loss: 0.0011
# EarlyStopping counter: 5/20
# Epoch [89/100] | Train Loss: 1.4145 | Val Loss: 0.0011
# Checkpoint saved! (val_loss: 0.0011)
# Epoch [90/100] | Train Loss: 1.4099 | Val Loss: 0.0011
# EarlyStopping counter: 1/20
# Epoch [91/100] | Train Loss: 1.4064 | Val Loss: 0.0011
# EarlyStopping counter: 2/20
# Epoch [92/100] | Train Loss: 1.4068 | Val Loss: 0.0011
# EarlyStopping counter: 3/20
# Epoch [93/100] | Train Loss: 1.4033 | Val Loss: 0.0011
# EarlyStopping counter: 4/20
# Epoch [94/100] | Train Loss: 1.3979 | Val Loss: 0.0011
# Checkpoint saved! (val_loss: 0.0011)
# Epoch [95/100] | Train Loss: 1.3947 | Val Loss: 0.0011
# EarlyStopping counter: 1/20
# Epoch [96/100] | Train Loss: 1.3949 | Val Loss: 0.0011
# EarlyStopping counter: 2/20
# Epoch [97/100] | Train Loss: 1.3896 | Val Loss: 0.0011
# EarlyStopping counter: 3/20
# Epoch [98/100] | Train Loss: 1.3869 | Val Loss: 0.0011
# Checkpoint saved! (val_loss: 0.0011)
# Epoch [99/100] | Train Loss: 1.3818 | Val Loss: 0.0011
# EarlyStopping counter: 1/20
# Epoch [100/100] | Train Loss: 1.3778 | Val Loss: 0.0011
# EarlyStopping counter: 2/20
# ============================================================
# TRAINING COMPLETED
# Best validation loss: 0.0011
# ============================================================

# %%
# Plot training curves
plot_losses(train_losses, val_losses)
# Out:
# Loss curve saved!
# Loss curve saved!
# Loss curve saved!
# Loss curve saved!
# Loss curve saved!
# Loss curve saved!
# Loss curve saved!
# Loss curve saved!
# Loss curve saved!
# Loss curve saved!
# Loss curve saved!
# Loss curve saved!
# Loss curve saved!
# Loss curve saved!
# Loss curve saved!
# Loss curve saved!
# Loss curve saved!
# Loss curve saved!
# Loss curve saved!
# Loss curve saved!
# Loss curve saved!
# Loss curve saved!
# Loss curve saved!
# Loss curve saved!
# Loss curve saved!
# Loss curve saved!
# Loss curve saved!
# Loss curve saved!
# Loss curve saved!
# Loss curve saved!
# Loss curve saved!
# Loss curve saved!
# Loss curve saved!
# Loss curve saved!
# Loss curve saved!
# Loss curve saved!
# Loss curve saved!
# Loss curve saved!
# Loss curve saved!
# Loss curve saved!
# Loss curve saved!
# Loss curve saved!
# Loss curve saved!
# Loss curve saved!
# Loss curve saved!
# Loss curve saved!
# Loss curve saved!
# Loss curve saved!
# Loss curve saved!
# Loss curve saved!
# Loss curve saved!
# Loss curve saved!
# Loss curve saved!
# Loss curve saved!
# Loss curve saved!
# Loss curve saved!
# Loss curve saved!
# Loss curve saved!
# Loss curve saved!
# Loss curve saved!
# Loss curve saved!
# Loss curve saved!
# Loss curve saved!
# Loss curve saved!
# Loss curve saved!
# Loss curve saved!
# Loss curve saved!
# Loss curve saved!
# Loss curve saved!
# Loss curve saved!
# Loss curve saved!
# Loss curve saved!
# Loss curve saved!
# Loss curve saved!
# Loss curve saved!
# Loss curve saved!
# Loss curve saved!
# Loss curve saved!
# Loss curve saved!
# Loss curve saved!
# Loss curve saved!
# Loss curve saved!
# Loss curve saved!
# Loss curve saved!
# Loss curve saved!
# Loss curve saved!
# Loss curve saved!
# Loss curve saved!
# Loss curve saved!
# Loss curve saved!
# Loss curve saved!
# Loss curve saved!
# Loss curve saved!
# Loss curve saved!
# Loss curve saved!
# Loss curve saved!
# Loss curve saved!
# Loss curve saved!
# Loss curve saved!
# Loss curve saved!
# Loss curve saved!
# Loss curve saved!
# Loss curve saved!
# Loss curve saved!
# Loss curve saved!
# Loss curve saved!
# Loss curve saved!
# Loss curve saved!
# Loss curve saved!
# Loss curve saved!
# Loss curve saved!
# Loss curve saved!
# Loss curve saved!
# Loss curve saved!
# Loss curve saved!
# Loss curve saved!
# Loss curve saved!
# Loss curve saved!
# Loss curve saved!
# Loss curve saved!
# Loss curve saved!
# Loss curve saved!
# Loss curve saved!
# Loss curve saved!
# Loss curve saved!
# Loss curve saved!
# Loss curve saved!
# Loss curve saved!
# Loss curve saved!
# Loss curve saved!
# Loss curve saved!
# Loss curve saved!
# Loss curve saved!
# Loss curve saved!
# Loss curve saved!
# Loss curve saved!
# Loss curve saved!
# Loss curve saved!
# Loss curve saved!
# Loss curve saved!
# Loss curve saved!
# Loss curve saved!
# Loss curve saved!
# Loss curve saved!
# Loss curve saved!
# Loss curve saved!
# Loss curve saved!
# Loss curve saved!
# Loss curve saved!
# Loss curve saved!
# Loss curve saved!
# Loss curve saved!
# Loss curve saved!
# Loss curve saved!
# Loss curve saved!
# Loss curve saved!
# Loss curve saved!
# Loss curve saved!
# Loss curve saved!
# Loss curve saved!
# Loss curve saved!
# Loss curve saved!
# Loss curve saved!
# Loss curve saved!
# Loss curve saved!
# Loss curve saved!
# Loss curve saved!
# Loss curve saved!
# Loss curve saved!
# Loss curve saved!
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-1156662312.py in <cell line: 0>()
#       1 # Plot training curves
# ----> 2 plot_losses(train_losses, val_losses)
#
# /tmp/ipython-input-3286807839.py in plot_losses(train_losses, val_losses)
#      12     #plt.close()
#      13     print("Loss curve saved!")
# ---> 14     plot_losses(train_losses, val_losses)
#
# /tmp/ipython-input-3286807839.py in plot_losses(train_losses, val_losses)
#      12     #plt.close()
#      13     print("Loss curve saved!")
# ---> 14     plot_losses(train_losses, val_losses)
#
# /tmp/ipython-input-3286807839.py in plot_losses(train_losses, val_losses)
#      12     #plt.close()
#      13     print("Loss curve saved!")
# ---> 14     plot_losses(train_losses, val_losses)
#
# /tmp/ipython-input-3286807839.py in plot_losses(train_losses, val_losses)
#      12     #plt.close()
#      13     print("Loss curve saved!")
# ---> 14     plot_losses(train_losses, val_losses)
#
# /tmp/ipython-input-3286807839.py in plot_losses(train_losses, val_losses)
#      12     #plt.close()
#      13     print("Loss curve saved!")
# ---> 14     plot_losses(train_losses, val_losses)
#
# /tmp/ipython-input-3286807839.py in plot_losses(train_losses, val_losses)
#      12     #plt.close()
#      13     print("Loss curve saved!")
# ---> 14     plot_losses(train_losses, val_losses)
#
# /tmp/ipython-input-3286807839.py in plot_losses(train_losses, val_losses)
#      12     #plt.close()
#      13     print("Loss curve saved!")
# ---> 14     plot_losses(train_losses, val_losses)
#
# /tmp/ipython-input-3286807839.py in plot_losses(train_losses, val_losses)
#      12     #plt.close()
#      13     print("Loss curve saved!")
# ---> 14     plot_losses(train_losses, val_losses)
#
# /tmp/ipython-input-3286807839.py in plot_losses(train_losses, val_losses)
#      12     #plt.close()
#      13     print("Loss curve saved!")
# ---> 14     plot_losses(train_losses, val_losses)
#
# /tmp/ipython-input-3286807839.py in plot_losses(train_losses, val_losses)
#      12     #plt.close()
#      13     print("Loss curve saved!")
# ---> 14     plot_losses(train_losses, val_losses)
#
# /tmp/ipython-input-3286807839.py in plot_losses(train_losses, val_losses)
#      12     #plt.close()
#      13     print("Loss curve saved!")
# ---> 14     plot_losses(train_losses, val_losses)
#
# /tmp/ipython-input-3286807839.py in plot_losses(train_losses, val_losses)
#      12     #plt.close()
#      13     print("Loss curve saved!")
# ---> 14     plot_losses(train_losses, val_losses)
#
# /tmp/ipython-input-3286807839.py in plot_losses(train_losses, val_losses)
#      12     #plt.close()
#      13     print("Loss curve saved!")
# ---> 14     plot_losses(train_losses, val_losses)
#
# /tmp/ipython-input-3286807839.py in plot_losses(train_losses, val_losses)
#      12     #plt.close()
#      13     print("Loss curve saved!")
# ---> 14     plot_losses(train_losses, val_losses)
#
# /tmp/ipython-input-3286807839.py in plot_losses(train_losses, val_losses)
#      12     #plt.close()
#      13     print("Loss curve saved!")
# ---> 14     plot_losses(train_losses, val_losses)
#
# /tmp/ipython-input-3286807839.py in plot_losses(train_losses, val_losses)
#      12     #plt.close()
#      13     print("Loss curve saved!")
# ---> 14     plot_losses(train_losses, val_losses)
#
# /tmp/ipython-input-3286807839.py in plot_losses(train_losses, val_losses)
#      12     #plt.close()
#      13     print("Loss curve saved!")
# ---> 14     plot_losses(train_losses, val_losses)
#
# /tmp/ipython-input-3286807839.py in plot_losses(train_losses, val_losses)
#      12     #plt.close()
#      13     print("Loss curve saved!")
# ---> 14     plot_losses(train_losses, val_losses)
#
# /tmp/ipython-input-3286807839.py in plot_losses(train_losses, val_losses)
#      12     #plt.close()
#      13     print("Loss curve saved!")
# ---> 14     plot_losses(train_losses, val_losses)
#
# /tmp/ipython-input-3286807839.py in plot_losses(train_losses, val_losses)
#      12     #plt.close()
#      13     print("Loss curve saved!")
# ---> 14     plot_losses(train_losses, val_losses)
#
# /tmp/ipython-input-3286807839.py in plot_losses(train_losses, val_losses)
#      12     #plt.close()
#      13     print("Loss curve saved!")
# ---> 14     plot_losses(train_losses, val_losses)
#
# /tmp/ipython-input-3286807839.py in plot_losses(train_losses, val_losses)
#      12     #plt.close()
#      13     print("Loss curve saved!")
# ---> 14     plot_losses(train_losses, val_losses)
#
# /tmp/ipython-input-3286807839.py in plot_losses(train_losses, val_losses)
#      12     #plt.close()
#      13     print("Loss curve saved!")
# ---> 14     plot_losses(train_losses, val_losses)
#
# /tmp/ipython-input-3286807839.py in plot_losses(train_losses, val_losses)
#      12     #plt.close()
#      13     print("Loss curve saved!")
# ---> 14     plot_losses(train_losses, val_losses)
#
# /tmp/ipython-input-3286807839.py in plot_losses(train_losses, val_losses)
#      12     #plt.close()
#      13     print("Loss curve saved!")
# ---> 14     plot_losses(train_losses, val_losses)
#
# /tmp/ipython-input-3286807839.py in plot_losses(train_losses, val_losses)
#      12     #plt.close()
#      13     print("Loss curve saved!")
# ---> 14     plot_losses(train_losses, val_losses)
#
# /tmp/ipython-input-3286807839.py in plot_losses(train_losses, val_losses)
#      12     #plt.close()
#      13     print("Loss curve saved!")
# ---> 14     plot_losses(train_losses, val_losses)
#
# /tmp/ipython-input-3286807839.py in plot_losses(train_losses, val_losses)
#      12     #plt.close()
#      13     print("Loss curve saved!")
# ---> 14     plot_losses(train_losses, val_losses)
#
# /tmp/ipython-input-3286807839.py in plot_losses(train_losses, val_losses)
#      12     #plt.close()
#      13     print("Loss curve saved!")
# ---> 14     plot_losses(train_losses, val_losses)
#
# /tmp/ipython-input-3286807839.py in plot_losses(train_losses, val_losses)
#      12     #plt.close()
#      13     print("Loss curve saved!")
# ---> 14     plot_losses(train_losses, val_losses)
#
# /tmp/ipython-input-3286807839.py in plot_losses(train_losses, val_losses)
#      12     #plt.close()
#      13     print("Loss curve saved!")
# ---> 14     plot_losses(train_losses, val_losses)
#
# /tmp/ipython-input-3286807839.py in plot_losses(train_losses, val_losses)
#      12     #plt.close()
#      13     print("Loss curve saved!")
# ---> 14     plot_losses(train_losses, val_losses)
#
# /tmp/ipython-input-3286807839.py in plot_losses(train_losses, val_losses)
#      12     #plt.close()
#      13     print("Loss curve saved!")
# ---> 14     plot_losses(train_losses, val_losses)
#
# /tmp/ipython-input-3286807839.py in plot_losses(train_losses, val_losses)
#      12     #plt.close()
#      13     print("Loss curve saved!")
# ---> 14     plot_losses(train_losses, val_losses)
#
# /tmp/ipython-input-3286807839.py in plot_losses(train_losses, val_losses)
#      12     #plt.close()
#      13     print("Loss curve saved!")
# ---> 14     plot_losses(train_losses, val_losses)
#
# /tmp/ipython-input-3286807839.py in plot_losses(train_losses, val_losses)
#      12     #plt.close()
#      13     print("Loss curve saved!")
# ---> 14     plot_losses(train_losses, val_losses)
#
# /tmp/ipython-input-3286807839.py in plot_losses(train_losses, val_losses)
#      12     #plt.close()
#      13     print("Loss curve saved!")
# ---> 14     plot_losses(train_losses, val_losses)
#
# /tmp/ipython-input-3286807839.py in plot_losses(train_losses, val_losses)
#      12     #plt.close()
#      13     print("Loss curve saved!")
# ---> 14     plot_losses(train_losses, val_losses)
#
# /tmp/ipython-input-3286807839.py in plot_losses(train_losses, val_losses)
#      12     #plt.close()
#      13     print("Loss curve saved!")
# ---> 14     plot_losses(train_losses, val_losses)
#
# /tmp/ipython-input-3286807839.py in plot_losses(train_losses, val_losses)
#      12     #plt.close()
#      13     print("Loss curve saved!")
# ---> 14     plot_losses(train_losses, val_losses)
#
# /tmp/ipython-input-3286807839.py in plot_losses(train_losses, val_losses)
#      12     #plt.close()
#      13     print("Loss curve saved!")
# ---> 14     plot_losses(train_losses, val_losses)
#
# /tmp/ipython-input-3286807839.py in plot_losses(train_losses, val_losses)
#      12     #plt.close()
#      13     print("Loss curve saved!")
# ---> 14     plot_losses(train_losses, val_losses)
#
# /tmp/ipython-input-3286807839.py in plot_losses(train_losses, val_losses)
#      12     #plt.close()
#      13     print("Loss curve saved!")
# ---> 14     plot_losses(train_losses, val_losses)
#
# /tmp/ipython-input-3286807839.py in plot_losses(train_losses, val_losses)
#      12     #plt.close()
#      13     print("Loss curve saved!")
# ---> 14     plot_losses(train_losses, val_losses)
#
# /tmp/ipython-input-3286807839.py in plot_losses(train_losses, val_losses)
#      12     #plt.close()
#      13     print("Loss curve saved!")
# ---> 14     plot_losses(train_losses, val_losses)
#
# /tmp/ipython-input-3286807839.py in plot_losses(train_losses, val_losses)
#      12     #plt.close()
#      13     print("Loss curve saved!")
# ---> 14     plot_losses(train_losses, val_losses)
#
# /tmp/ipython-input-3286807839.py in plot_losses(train_losses, val_losses)
#      12     #plt.close()
#      13     print("Loss curve saved!")
# ---> 14     plot_losses(train_losses, val_losses)
#
# /tmp/ipython-input-3286807839.py in plot_losses(train_losses, val_losses)
#      12     #plt.close()
#      13     print("Loss curve saved!")
# ---> 14     plot_losses(train_losses, val_losses)
#
# /tmp/ipython-input-3286807839.py in plot_losses(train_losses, val_losses)
#      12     #plt.close()
#      13     print("Loss curve saved!")
# ---> 14     plot_losses(train_losses, val_losses)
#
# /tmp/ipython-input-3286807839.py in plot_losses(train_losses, val_losses)
#      12     #plt.close()
#      13     print("Loss curve saved!")
# ---> 14     plot_losses(train_losses, val_losses)
#
# /tmp/ipython-input-3286807839.py in plot_losses(train_losses, val_losses)
#      12     #plt.close()
#      13     print("Loss curve saved!")
# ---> 14     plot_losses(train_losses, val_losses)
#
# /tmp/ipython-input-3286807839.py in plot_losses(train_losses, val_losses)
#      12     #plt.close()
#      13     print("Loss curve saved!")
# ---> 14     plot_losses(train_losses, val_losses)
#
# /tmp/ipython-input-3286807839.py in plot_losses(train_losses, val_losses)
#      12     #plt.close()
#      13     print("Loss curve saved!")
# ---> 14     plot_losses(train_losses, val_losses)
#
# /tmp/ipython-input-3286807839.py in plot_losses(train_losses, val_losses)
#      12     #plt.close()
#      13     print("Loss curve saved!")
# ---> 14     plot_losses(train_losses, val_losses)
#
# /tmp/ipython-input-3286807839.py in plot_losses(train_losses, val_losses)
#      12     #plt.close()
#      13     print("Loss curve saved!")
# ---> 14     plot_losses(train_losses, val_losses)
#
# /tmp/ipython-input-3286807839.py in plot_losses(train_losses, val_losses)
#      12     #plt.close()
#      13     print("Loss curve saved!")
# ---> 14     plot_losses(train_losses, val_losses)
#
# /tmp/ipython-input-3286807839.py in plot_losses(train_losses, val_losses)
#      12     #plt.close()
#      13     print("Loss curve saved!")
# ---> 14     plot_losses(train_losses, val_losses)
#
# /tmp/ipython-input-3286807839.py in plot_losses(train_losses, val_losses)
#      12     #plt.close()
#      13     print("Loss curve saved!")
# ---> 14     plot_losses(train_losses, val_losses)
#
# /tmp/ipython-input-3286807839.py in plot_losses(train_losses, val_losses)
#      12     #plt.close()
#      13     print("Loss curve saved!")
# ---> 14     plot_losses(train_losses, val_losses)
#
# /tmp/ipython-input-3286807839.py in plot_losses(train_losses, val_losses)
#      12     #plt.close()
#      13     print("Loss curve saved!")
# ---> 14     plot_losses(train_losses, val_losses)
#
# /tmp/ipython-input-3286807839.py in plot_losses(train_losses, val_losses)
#      12     #plt.close()
#      13     print("Loss curve saved!")
# ---> 14     plot_losses(train_losses, val_losses)
#
# /tmp/ipython-input-3286807839.py in plot_losses(train_losses, val_losses)
#      12     #plt.close()
#      13     print("Loss curve saved!")
# ---> 14     plot_losses(train_losses, val_losses)
#
# /tmp/ipython-input-3286807839.py in plot_losses(train_losses, val_losses)
#      12     #plt.close()
#      13     print("Loss curve saved!")
# ---> 14     plot_losses(train_losses, val_losses)
#
# /tmp/ipython-input-3286807839.py in plot_losses(train_losses, val_losses)
#      12     #plt.close()
#      13     print("Loss curve saved!")
# ---> 14     plot_losses(train_losses, val_losses)
#
# /tmp/ipython-input-3286807839.py in plot_losses(train_losses, val_losses)
#      12     #plt.close()
#      13     print("Loss curve saved!")
# ---> 14     plot_losses(train_losses, val_losses)
#
# /tmp/ipython-input-3286807839.py in plot_losses(train_losses, val_losses)
#      12     #plt.close()
#      13     print("Loss curve saved!")
# ---> 14     plot_losses(train_losses, val_losses)
#
# /tmp/ipython-input-3286807839.py in plot_losses(train_losses, val_losses)
#      12     #plt.close()
#      13     print("Loss curve saved!")
# ---> 14     plot_losses(train_losses, val_losses)
#
# /tmp/ipython-input-3286807839.py in plot_losses(train_losses, val_losses)
#      12     #plt.close()
#      13     print("Loss curve saved!")
# ---> 14     plot_losses(train_losses, val_losses)
#
# /tmp/ipython-input-3286807839.py in plot_losses(train_losses, val_losses)
#      12     #plt.close()
#      13     print("Loss curve saved!")
# ---> 14     plot_losses(train_losses, val_losses)
#
# /tmp/ipython-input-3286807839.py in plot_losses(train_losses, val_losses)
#      12     #plt.close()
#      13     print("Loss curve saved!")
# ---> 14     plot_losses(train_losses, val_losses)
#
# /tmp/ipython-input-3286807839.py in plot_losses(train_losses, val_losses)
#      12     #plt.close()
#      13     print("Loss curve saved!")
# ---> 14     plot_losses(train_losses, val_losses)
#
# /tmp/ipython-input-3286807839.py in plot_losses(train_losses, val_losses)
#      12     #plt.close()
#      13     print("Loss curve saved!")
# ---> 14     plot_losses(train_losses, val_losses)
#
# /tmp/ipython-input-3286807839.py in plot_losses(train_losses, val_losses)
#      12     #plt.close()
#      13     print("Loss curve saved!")
# ---> 14     plot_losses(train_losses, val_losses)
#
# /tmp/ipython-input-3286807839.py in plot_losses(train_losses, val_losses)
#      12     #plt.close()
#      13     print("Loss curve saved!")
# ---> 14     plot_losses(train_losses, val_losses)
#
# /tmp/ipython-input-3286807839.py in plot_losses(train_losses, val_losses)
#      12     #plt.close()
#      13     print("Loss curve saved!")
# ---> 14     plot_losses(train_losses, val_losses)
#
# /tmp/ipython-input-3286807839.py in plot_losses(train_losses, val_losses)
#      12     #plt.close()
#      13     print("Loss curve saved!")
# ---> 14     plot_losses(train_losses, val_losses)
#
# /tmp/ipython-input-3286807839.py in plot_losses(train_losses, val_losses)
#      12     #plt.close()
#      13     print("Loss curve saved!")
# ---> 14     plot_losses(train_losses, val_losses)
#
# /tmp/ipython-input-3286807839.py in plot_losses(train_losses, val_losses)
#      12     #plt.close()
#      13     print("Loss curve saved!")
# ---> 14     plot_losses(train_losses, val_losses)
#
# /tmp/ipython-input-3286807839.py in plot_losses(train_losses, val_losses)
#      12     #plt.close()
#      13     print("Loss curve saved!")
# ---> 14     plot_losses(train_losses, val_losses)
#
# /tmp/ipython-input-3286807839.py in plot_losses(train_losses, val_losses)
#      12     #plt.close()
#      13     print("Loss curve saved!")
# ---> 14     plot_losses(train_losses, val_losses)
#
# /tmp/ipython-input-3286807839.py in plot_losses(train_losses, val_losses)
#      12     #plt.close()
#      13     print("Loss curve saved!")
# ---> 14     plot_losses(train_losses, val_losses)
#
# /tmp/ipython-input-3286807839.py in plot_losses(train_losses, val_losses)
#      12     #plt.close()
#      13     print("Loss curve saved!")
# ---> 14     plot_losses(train_losses, val_losses)
#
# /tmp/ipython-input-3286807839.py in plot_losses(train_losses, val_losses)
#      12     #plt.close()
#      13     print("Loss curve saved!")
# ---> 14     plot_losses(train_losses, val_losses)
#
# /tmp/ipython-input-3286807839.py in plot_losses(train_losses, val_losses)
#      12     #plt.close()
#      13     print("Loss curve saved!")
# ---> 14     plot_losses(train_losses, val_losses)
#
# /tmp/ipython-input-3286807839.py in plot_losses(train_losses, val_losses)
#      12     #plt.close()
#      13     print("Loss curve saved!")
# ---> 14     plot_losses(train_losses, val_losses)
#
# /tmp/ipython-input-3286807839.py in plot_losses(train_losses, val_losses)
#      12     #plt.close()
#      13     print("Loss curve saved!")
# ---> 14     plot_losses(train_losses, val_losses)
#
# /tmp/ipython-input-3286807839.py in plot_losses(train_losses, val_losses)
#      12     #plt.close()
#      13     print("Loss curve saved!")
# ---> 14     plot_losses(train_losses, val_losses)
#
# /tmp/ipython-input-3286807839.py in plot_losses(train_losses, val_losses)
#      12     #plt.close()
#      13     print("Loss curve saved!")
# ---> 14     plot_losses(train_losses, val_losses)
#
# /tmp/ipython-input-3286807839.py in plot_losses(train_losses, val_losses)
#      12     #plt.close()
#      13     print("Loss curve saved!")
# ---> 14     plot_losses(train_losses, val_losses)
#
# /tmp/ipython-input-3286807839.py in plot_losses(train_losses, val_losses)
#      12     #plt.close()
#      13     print("Loss curve saved!")
# ---> 14     plot_losses(train_losses, val_losses)
#
# /tmp/ipython-input-3286807839.py in plot_losses(train_losses, val_losses)
#      12     #plt.close()
#      13     print("Loss curve saved!")
# ---> 14     plot_losses(train_losses, val_losses)
#
# /tmp/ipython-input-3286807839.py in plot_losses(train_losses, val_losses)
#      12     #plt.close()
#      13     print("Loss curve saved!")
# ---> 14     plot_losses(train_losses, val_losses)
#
# /tmp/ipython-input-3286807839.py in plot_losses(train_losses, val_losses)
#      12     #plt.close()
#      13     print("Loss curve saved!")
# ---> 14     plot_losses(train_losses, val_losses)
#
# /tmp/ipython-input-3286807839.py in plot_losses(train_losses, val_losses)
#      12     #plt.close()
#      13     print("Loss curve saved!")
# ---> 14     plot_losses(train_losses, val_losses)
#
# /tmp/ipython-input-3286807839.py in plot_losses(train_losses, val_losses)
#      12     #plt.close()
#      13     print("Loss curve saved!")
# ---> 14     plot_losses(train_losses, val_losses)
#
# /tmp/ipython-input-3286807839.py in plot_losses(train_losses, val_losses)
#      12     #plt.close()
#      13     print("Loss curve saved!")
# ---> 14     plot_losses(train_losses, val_losses)
#
# /tmp/ipython-input-3286807839.py in plot_losses(train_losses, val_losses)
#      12     #plt.close()
#      13     print("Loss curve saved!")
# ---> 14     plot_losses(train_losses, val_losses)
#
# /tmp/ipython-input-3286807839.py in plot_losses(train_losses, val_losses)
#      12     #plt.close()
#      13     print("Loss curve saved!")
# ---> 14     plot_losses(train_losses, val_losses)
#
# /tmp/ipython-input-3286807839.py in plot_losses(train_losses, val_losses)
#      12     #plt.close()
#      13     print("Loss curve saved!")
# ---> 14     plot_losses(train_losses, val_losses)
#
# /tmp/ipython-input-3286807839.py in plot_losses(train_losses, val_losses)
#      12     #plt.close()
#      13     print("Loss curve saved!")
# ---> 14     plot_losses(train_losses, val_losses)
#
# /tmp/ipython-input-3286807839.py in plot_losses(train_losses, val_losses)
#      12     #plt.close()
#      13     print("Loss curve saved!")
# ---> 14     plot_losses(train_losses, val_losses)
#
# /tmp/ipython-input-3286807839.py in plot_losses(train_losses, val_losses)
#      12     #plt.close()
#      13     print("Loss curve saved!")
# ---> 14     plot_losses(train_losses, val_losses)
#
# /tmp/ipython-input-3286807839.py in plot_losses(train_losses, val_losses)
#      12     #plt.close()
#      13     print("Loss curve saved!")
# ---> 14     plot_losses(train_losses, val_losses)
#
# /tmp/ipython-input-3286807839.py in plot_losses(train_losses, val_losses)
#      12     #plt.close()
#      13     print("Loss curve saved!")
# ---> 14     plot_losses(train_losses, val_losses)
#
# /tmp/ipython-input-3286807839.py in plot_losses(train_losses, val_losses)
#      12     #plt.close()
#      13     print("Loss curve saved!")
# ---> 14     plot_losses(train_losses, val_losses)
#
# /tmp/ipython-input-3286807839.py in plot_losses(train_losses, val_losses)
#      12     #plt.close()
#      13     print("Loss curve saved!")
# ---> 14     plot_losses(train_losses, val_losses)
#
# /tmp/ipython-input-3286807839.py in plot_losses(train_losses, val_losses)
#      12     #plt.close()
#      13     print("Loss curve saved!")
# ---> 14     plot_losses(train_losses, val_losses)
#
# /tmp/ipython-input-3286807839.py in plot_losses(train_losses, val_losses)
#      12     #plt.close()
#      13     print("Loss curve saved!")
# ---> 14     plot_losses(train_losses, val_losses)
#
# /tmp/ipython-input-3286807839.py in plot_losses(train_losses, val_losses)
#      12     #plt.close()
#      13     print("Loss curve saved!")
# ---> 14     plot_losses(train_losses, val_losses)
#
# /tmp/ipython-input-3286807839.py in plot_losses(train_losses, val_losses)
#      12     #plt.close()
#      13     print("Loss curve saved!")
# ---> 14     plot_losses(train_losses, val_losses)
#
# /tmp/ipython-input-3286807839.py in plot_losses(train_losses, val_losses)
#      12     #plt.close()
#      13     print("Loss curve saved!")
# ---> 14     plot_losses(train_losses, val_losses)
#
# /tmp/ipython-input-3286807839.py in plot_losses(train_losses, val_losses)
#      12     #plt.close()
#      13     print("Loss curve saved!")
# ---> 14     plot_losses(train_losses, val_losses)
#
# /tmp/ipython-input-3286807839.py in plot_losses(train_losses, val_losses)
#      12     #plt.close()
#      13     print("Loss curve saved!")
# ---> 14     plot_losses(train_losses, val_losses)
#
# /tmp/ipython-input-3286807839.py in plot_losses(train_losses, val_losses)
#      12     #plt.close()
#      13     print("Loss curve saved!")
# ---> 14     plot_losses(train_losses, val_losses)
#
# /tmp/ipython-input-3286807839.py in plot_losses(train_losses, val_losses)
#      12     #plt.close()
#      13     print("Loss curve saved!")
# ---> 14     plot_losses(train_losses, val_losses)
#
# /tmp/ipython-input-3286807839.py in plot_losses(train_losses, val_losses)
#      12     #plt.close()
#      13     print("Loss curve saved!")
# ---> 14     plot_losses(train_losses, val_losses)
#
# /tmp/ipython-input-3286807839.py in plot_losses(train_losses, val_losses)
#      12     #plt.close()
#      13     print("Loss curve saved!")
# ---> 14     plot_losses(train_losses, val_losses)
#
# /tmp/ipython-input-3286807839.py in plot_losses(train_losses, val_losses)
#      12     #plt.close()
#      13     print("Loss curve saved!")
# ---> 14     plot_losses(train_losses, val_losses)
#
# /tmp/ipython-input-3286807839.py in plot_losses(train_losses, val_losses)
#      12     #plt.close()
#      13     print("Loss curve saved!")
# ---> 14     plot_losses(train_losses, val_losses)
#
# /tmp/ipython-input-3286807839.py in plot_losses(train_losses, val_losses)
#      12     #plt.close()
#      13     print("Loss curve saved!")
# ---> 14     plot_losses(train_losses, val_losses)
#
# /tmp/ipython-input-3286807839.py in plot_losses(train_losses, val_losses)
#      12     #plt.close()
#      13     print("Loss curve saved!")
# ---> 14     plot_losses(train_losses, val_losses)
#
# /tmp/ipython-input-3286807839.py in plot_losses(train_losses, val_losses)
#      12     #plt.close()
#      13     print("Loss curve saved!")
# ---> 14     plot_losses(train_losses, val_losses)
#
# /tmp/ipython-input-3286807839.py in plot_losses(train_losses, val_losses)
#      12     #plt.close()
#      13     print("Loss curve saved!")
# ---> 14     plot_losses(train_losses, val_losses)
#
# /tmp/ipython-input-3286807839.py in plot_losses(train_losses, val_losses)
#      12     #plt.close()
#      13     print("Loss curve saved!")
# ---> 14     plot_losses(train_losses, val_losses)
#
# /tmp/ipython-input-3286807839.py in plot_losses(train_losses, val_losses)
#      12     #plt.close()
#      13     print("Loss curve saved!")
# ---> 14     plot_losses(train_losses, val_losses)
#
# /tmp/ipython-input-3286807839.py in plot_losses(train_losses, val_losses)
#      12     #plt.close()
#      13     print("Loss curve saved!")
# ---> 14     plot_losses(train_losses, val_losses)
#
# /tmp/ipython-input-3286807839.py in plot_losses(train_losses, val_losses)
#      12     #plt.close()
#      13     print("Loss curve saved!")
# ---> 14     plot_losses(train_losses, val_losses)
#
# /tmp/ipython-input-3286807839.py in plot_losses(train_losses, val_losses)
#      12     #plt.close()
#      13     print("Loss curve saved!")
# ---> 14     plot_losses(train_losses, val_losses)
#
# /tmp/ipython-input-3286807839.py in plot_losses(train_losses, val_losses)
#      12     #plt.close()
#      13     print("Loss curve saved!")
# ---> 14     plot_losses(train_losses, val_losses)
#
# /tmp/ipython-input-3286807839.py in plot_losses(train_losses, val_losses)
#      12     #plt.close()
#      13     print("Loss curve saved!")
# ---> 14     plot_losses(train_losses, val_losses)
#
# /tmp/ipython-input-3286807839.py in plot_losses(train_losses, val_losses)
#      12     #plt.close()
#      13     print("Loss curve saved!")
# ---> 14     plot_losses(train_losses, val_losses)
#
# /tmp/ipython-input-3286807839.py in plot_losses(train_losses, val_losses)
#      12     #plt.close()
#      13     print("Loss curve saved!")
# ---> 14     plot_losses(train_losses, val_losses)
#
# /tmp/ipython-input-3286807839.py in plot_losses(train_losses, val_losses)
#      12     #plt.close()
#      13     print("Loss curve saved!")
# ---> 14     plot_losses(train_losses, val_losses)
#
# /tmp/ipython-input-3286807839.py in plot_losses(train_losses, val_losses)
#      12     #plt.close()
#      13     print("Loss curve saved!")
# ---> 14     plot_losses(train_losses, val_losses)
#
# /tmp/ipython-input-3286807839.py in plot_losses(train_losses, val_losses)
#      12     #plt.close()
#      13     print("Loss curve saved!")
# ---> 14     plot_losses(train_losses, val_losses)
#
# /tmp/ipython-input-3286807839.py in plot_losses(train_losses, val_losses)
#      12     #plt.close()
#      13     print("Loss curve saved!")
# ---> 14     plot_losses(train_losses, val_losses)
#
# /tmp/ipython-input-3286807839.py in plot_losses(train_losses, val_losses)
#      12     #plt.close()
#      13     print("Loss curve saved!")
# ---> 14     plot_losses(train_losses, val_losses)
#
# /tmp/ipython-input-3286807839.py in plot_losses(train_losses, val_losses)
#      12     #plt.close()
#      13     print("Loss curve saved!")
# ---> 14     plot_losses(train_losses, val_losses)
#
# /tmp/ipython-input-3286807839.py in plot_losses(train_losses, val_losses)
#      12     #plt.close()
#      13     print("Loss curve saved!")
# ---> 14     plot_losses(train_losses, val_losses)
#
# /tmp/ipython-input-3286807839.py in plot_losses(train_losses, val_losses)
#      12     #plt.close()
#      13     print("Loss curve saved!")
# ---> 14     plot_losses(train_losses, val_losses)
#
# /tmp/ipython-input-3286807839.py in plot_losses(train_losses, val_losses)
#      12     #plt.close()
#      13     print("Loss curve saved!")
# ---> 14     plot_losses(train_losses, val_losses)
#
# /tmp/ipython-input-3286807839.py in plot_losses(train_losses, val_losses)
#      12     #plt.close()
#      13     print("Loss curve saved!")
# ---> 14     plot_losses(train_losses, val_losses)
#
# /tmp/ipython-input-3286807839.py in plot_losses(train_losses, val_losses)
#      12     #plt.close()
#      13     print("Loss curve saved!")
# ---> 14     plot_losses(train_losses, val_losses)
#
# /tmp/ipython-input-3286807839.py in plot_losses(train_losses, val_losses)
#      12     #plt.close()
#      13     print("Loss curve saved!")
# ---> 14     plot_losses(train_losses, val_losses)
#
# /tmp/ipython-input-3286807839.py in plot_losses(train_losses, val_losses)
#      12     #plt.close()
#      13     print("Loss curve saved!")
# ---> 14     plot_losses(train_losses, val_losses)
#
# /tmp/ipython-input-3286807839.py in plot_losses(train_losses, val_losses)
#      12     #plt.close()
#      13     print("Loss curve saved!")
# ---> 14     plot_losses(train_losses, val_losses)
#
# /tmp/ipython-input-3286807839.py in plot_losses(train_losses, val_losses)
#      12     #plt.close()
#      13     print("Loss curve saved!")
# ---> 14     plot_losses(train_losses, val_losses)
#
# /tmp/ipython-input-3286807839.py in plot_losses(train_losses, val_losses)
#      12     #plt.close()
#      13     print("Loss curve saved!")
# ---> 14     plot_losses(train_losses, val_losses)
#
# /tmp/ipython-input-3286807839.py in plot_losses(train_losses, val_losses)
#      12     #plt.close()
#      13     print("Loss curve saved!")
# ---> 14     plot_losses(train_losses, val_losses)
#
# /tmp/ipython-input-3286807839.py in plot_losses(train_losses, val_losses)
#      12     #plt.close()
#      13     print("Loss curve saved!")
# ---> 14     plot_losses(train_losses, val_losses)
#
# /tmp/ipython-input-3286807839.py in plot_losses(train_losses, val_losses)
#      12     #plt.close()
#      13     print("Loss curve saved!")
# ---> 14     plot_losses(train_losses, val_losses)
#
# /tmp/ipython-input-3286807839.py in plot_losses(train_losses, val_losses)
#      12     #plt.close()
#      13     print("Loss curve saved!")
# ---> 14     plot_losses(train_losses, val_losses)
#
# /tmp/ipython-input-3286807839.py in plot_losses(train_losses, val_losses)
#      12     #plt.close()
#      13     print("Loss curve saved!")
# ---> 14     plot_losses(train_losses, val_losses)
#
# /tmp/ipython-input-3286807839.py in plot_losses(train_losses, val_losses)
#      12     #plt.close()
#      13     print("Loss curve saved!")
# ---> 14     plot_losses(train_losses, val_losses)
#
# /tmp/ipython-input-3286807839.py in plot_losses(train_losses, val_losses)
#      12     #plt.close()
#      13     print("Loss curve saved!")
# ---> 14     plot_losses(train_losses, val_losses)
#
# /tmp/ipython-input-3286807839.py in plot_losses(train_losses, val_losses)
#      12     #plt.close()
#      13     print("Loss curve saved!")
# ---> 14     plot_losses(train_losses, val_losses)
#
# /tmp/ipython-input-3286807839.py in plot_losses(train_losses, val_losses)
#      12     #plt.close()
#      13     print("Loss curve saved!")
# ---> 14     plot_losses(train_losses, val_losses)
#
# /tmp/ipython-input-3286807839.py in plot_losses(train_losses, val_losses)
#      12     #plt.close()
#      13     print("Loss curve saved!")
# ---> 14     plot_losses(train_losses, val_losses)
#
# /tmp/ipython-input-3286807839.py in plot_losses(train_losses, val_losses)
#      12     #plt.close()
#      13     print("Loss curve saved!")
# ---> 14     plot_losses(train_losses, val_losses)
#
# /tmp/ipython-input-3286807839.py in plot_losses(train_losses, val_losses)
#      12     #plt.close()
#      13     print("Loss curve saved!")
# ---> 14     plot_losses(train_losses, val_losses)
#
# /tmp/ipython-input-3286807839.py in plot_losses(train_losses, val_losses)
#      12     #plt.close()
#      13     print("Loss curve saved!")
# ---> 14     plot_losses(train_losses, val_losses)
#
# /tmp/ipython-input-3286807839.py in plot_losses(train_losses, val_losses)
#      12     #plt.close()
#      13     print("Loss curve saved!")
# ---> 14     plot_losses(train_losses, val_losses)
#
# /tmp/ipython-input-3286807839.py in plot_losses(train_losses, val_losses)
#      12     #plt.close()
#      13     print("Loss curve saved!")
# ---> 14     plot_losses(train_losses, val_losses)
#
# /tmp/ipython-input-3286807839.py in plot_losses(train_losses, val_losses)
#      12     #plt.close()
#      13     print("Loss curve saved!")
# ---> 14     plot_losses(train_losses, val_losses)
#
# /tmp/ipython-input-3286807839.py in plot_losses(train_losses, val_losses)
#      12     #plt.close()
#      13     print("Loss curve saved!")
# ---> 14     plot_losses(train_losses, val_losses)
#
# /tmp/ipython-input-3286807839.py in plot_losses(train_losses, val_losses)
#      12     #plt.close()
#      13     print("Loss curve saved!")
# ---> 14     plot_losses(train_losses, val_losses)
#
# /tmp/ipython-input-3286807839.py in plot_losses(train_losses, val_losses)
#      12     #plt.close()
#      13     print("Loss curve saved!")
# ---> 14     plot_losses(train_losses, val_losses)
#
# /tmp/ipython-input-3286807839.py in plot_losses(train_losses, val_losses)
#      12     #plt.close()
#      13     print("Loss curve saved!")
# ---> 14     plot_losses(train_losses, val_losses)
#
# /tmp/ipython-input-3286807839.py in plot_losses(train_losses, val_losses)
#      12     #plt.close()
#      13     print("Loss curve saved!")
# ---> 14     plot_losses(train_losses, val_losses)
#
# /tmp/ipython-input-3286807839.py in plot_losses(train_losses, val_losses)
#      12     #plt.close()
#      13     print("Loss curve saved!")
# ---> 14     plot_losses(train_losses, val_losses)
#
# /tmp/ipython-input-3286807839.py in plot_losses(train_losses, val_losses)
#       7     plt.legend()
#       8     plt.grid()
# ----> 9     plt.tight_layout()
#      10     plt.show()
#      11     #plt.savefig("loss_curve.png")  # 👈 ASIL OLAY
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/pyplot.py in tight_layout(pad, h_pad, w_pad, rect)
#    2833     rect: tuple[float, float, float, float] | None = None,
#    2834 ) -> None:
# -> 2835     gcf().tight_layout(pad=pad, h_pad=h_pad, w_pad=w_pad, rect=rect)
#    2836
#    2837
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/figure.py in tight_layout(self, pad, h_pad, w_pad, rect)
#    3638             previous_engine = self.get_layout_engine()
#    3639             self.set_layout_engine(engine)
# -> 3640             engine.execute(self)
#    3641             if previous_engine is not None and not isinstance(
#    3642                 previous_engine, (TightLayoutEngine, PlaceHolderLayoutEngine)
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/layout_engine.py in execute(self, fig)
#     181         renderer = fig._get_renderer()
#     182         with getattr(renderer, "_draw_disabled", nullcontext)():
# --> 183             kwargs = get_tight_layout_figure(
#     184                 fig, fig.axes, get_subplotspec_list(fig.axes), renderer,
#     185                 pad=info['pad'], h_pad=info['h_pad'], w_pad=info['w_pad'],
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/_tight_layout.py in get_tight_layout_figure(fig, axes_list, subplotspec_list, renderer, pad, h_pad, w_pad, rect)
#     264             slice(ss.colspan.start * div_col, ss.colspan.stop * div_col)))
#     265
# --> 266     kwargs = _auto_adjust_subplotpars(fig, renderer,
#     267                                       shape=(max_nrows, max_ncols),
#     268                                       span_pairs=span_pairs,
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/_tight_layout.py in _auto_adjust_subplotpars(fig, renderer, shape, span_pairs, subplot_list, ax_bbox_list, pad, h_pad, w_pad, rect)
#      80         for ax in subplots:
#      81             if ax.get_visible():
# ---> 82                 bb += [martist._get_tightbbox_for_layout_only(ax, renderer)]
#      83
#      84         tight_bbox_raw = Bbox.union(bb)
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/artist.py in _get_tightbbox_for_layout_only(obj, *args, **kwargs)
#    1400     """
#    1401     try:
# -> 1402         return obj.get_tightbbox(*args, **{**kwargs, "for_layout_only": True})
#    1403     except TypeError:
#    1404         return obj.get_tightbbox(*args, **kwargs)
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/axes/_base.py in get_tightbbox(self, renderer, call_axes_locator, bbox_extra_artists, for_layout_only)
#    4517         for axis in self._axis_map.values():
#    4518             if self.axison and axis.get_visible():
# -> 4519                 ba = martist._get_tightbbox_for_layout_only(axis, renderer)
#    4520                 if ba:
#    4521                     bb.append(ba)
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/artist.py in _get_tightbbox_for_layout_only(obj, *args, **kwargs)
#    1400     """
#    1401     try:
# -> 1402         return obj.get_tightbbox(*args, **{**kwargs, "for_layout_only": True})
#    1403     except TypeError:
#    1404         return obj.get_tightbbox(*args, **kwargs)
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/axis.py in get_tightbbox(self, renderer, for_layout_only)
#    1360         if renderer is None:
#    1361             renderer = self.get_figure(root=True)._get_renderer()
# -> 1362         ticks_to_draw = self._update_ticks()
#    1363
#    1364         self._update_label_position(renderer)
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/axis.py in _update_ticks(self)
#    1292         major_locs = self.get_majorticklocs()
#    1293         major_labels = self.major.formatter.format_ticks(major_locs)
# -> 1294         major_ticks = self.get_major_ticks(len(major_locs))
#    1295         for tick, loc, label in zip(major_ticks, major_locs, major_labels):
#    1296             tick.update_position(loc)
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/axis.py in get_major_ticks(self, numticks)
#    1673         while len(self.majorTicks) < numticks:
#    1674             # Update the new tick label properties from the old.
# -> 1675             tick = self._get_tick(major=True)
#    1676             self.majorTicks.append(tick)
#    1677             self._copy_tick_props(self.majorTicks[0], tick)
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/axis.py in _get_tick(self, major)
#    1601                 "_tick_class or reimplement _get_tick()")
#    1602         tick_kw = self._major_tick_kw if major else self._minor_tick_kw
# -> 1603         return self._tick_class(self.axes, 0, major=major, **tick_kw)
#    1604
#    1605     def _get_tick_label_size(self, axis_name):
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/axis.py in __init__(self, *args, **kwargs)
#     366
#     367     def __init__(self, *args, **kwargs):
# --> 368         super().__init__(*args, **kwargs)
#     369         # x in data coords, y in axes coords
#     370         ax = self.axes
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/axis.py in __init__(self, axes, loc, size, width, color, tickdir, pad, labelsize, labelcolor, labelfontfamily, zorder, gridOn, tick1On, tick2On, label1On, label2On, major, labelrotation, grid_color, grid_linestyle, grid_linewidth, grid_alpha, **kwargs)
#     157             markeredgecolor=color, markersize=size, markeredgewidth=width,
#     158         )
# --> 159         self.tick2line = mlines.Line2D(
#     160             [], [],
#     161             color=color, linestyle="none", zorder=zorder, visible=tick2On,
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/lines.py in __init__(self, xdata, ydata, linewidth, linestyle, color, gapcolor, marker, markersize, markeredgewidth, markeredgecolor, markerfacecolor, markerfacecoloralt, fillstyle, antialiased, dash_capstyle, solid_capstyle, dash_joinstyle, solid_joinstyle, pickradius, drawstyle, markevery, **kwargs)
#     405         # update kwargs before updating data to give the caller a
#     406         # chance to init axes (and hence unit support)
# --> 407         self._internal_update(kwargs)
#     408         self.pickradius = pickradius
#     409         self.ind_offset = 0
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/artist.py in _internal_update(self, kwargs)
#    1231         The lack of prenormalization is to maintain backcompatibility.
#    1232         """
# -> 1233         return self._update_props(
#    1234             kwargs, "{cls.__name__}.set() got an unexpected keyword argument "
#    1235             "{prop_name!r}")
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/artist.py in _update_props(self, props, errfmt)
#    1209                     ret.append(func(v))
#    1210         if ret:
# -> 1211             self.pchanged()
#    1212             self.stale = True
#    1213         return ret
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/artist.py in pchanged(self)
#     423         remove_callback
#     424         """
# --> 425         self._callbacks.process("pchanged")
#     426
#     427     def is_transform_set(self):
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/cbook.py in process(self, s, *args, **kwargs)
#     355         if self._signals is not None:
#     356             _api.check_in_list(self._signals, signal=s)
# --> 357         for ref in list(self.callbacks.get(s, {}).values()):
#     358             func = ref()
#     359             if func is not None:
#
# KeyboardInterrupt:

# %%
# Evaluate on test set
test_model(model)
# Out:
# TEST ACCURACY: 0.8436 (84.36%)
# 0.8436

# %% [markdown]
# ## Section 10: Hyperparameter Tuning - Grid Search
#
# ### CONCEPT: Grid Search
#
# Grid Search systematically tries **ALL combinations** of hyperparameters. It is exponentially expensive (3 × 3 × 3 × 2 = 54 combinations). If each training takes 2 minutes, 54 combos = 108 minutes :(((

# %%
# Hyperparameter search space for experimentation. You can reduce the options for quicker
#runs.
param_grid = {
    'lr': [0.0001, 0.001],       # Learning rates
    'dropout_rate': [0.3, 0.5, 0.7],         # Dropout rates
    'l1_lambda': [0.0, 0.001],               # L1 regularization
    'l2_lambda': [0.0, 0.001],               # L2 regularization
    'weight_init': ['xavier', 'kaiming']     # Initialization methods
}

# %%
import itertools
import copy

def grid_search(param_grid):
    """
    Perform grid search over hyperparameter space.

    Args:
        param_grid: Dictionary of hyperparameter lists to search

    Returns:
        best_model: Model with best validation loss
        best_params: Dictionary of best hyperparameters
    """
    param_grid = {
    "l1_lambda": [0.0, 0.0001],
    "l2_lambda": [0.001, 0.01],
    "dropout_rate": [0.2, 0.3],
    "lr": [0.001, 0.0005]
    }

    best_val_loss = float('inf')
    best_params = None
    best_model = None

    # -------------------------------------------------------------------------
    # TODO 13: Generate all hyperparameter combinations
    # -------------------------------------------------------------------------
    # HINT:
    #   keys = list(param_grid.keys())
    #   combinations = use itertools.product to get all combos
    #
    #   Then iterate: for combo in combinations:
    #       params = dict(zip(keys, combo))
    # -------------------------------------------------------------------------

    keys = list(param_grid.keys())
    combinations = list(itertools.product(*param_grid.values()))

    print(f"Grid Search: Testing {len(combinations)} combinations\n")

    for i, combo in enumerate(combinations):
        params = dict(zip(keys, combo))

        print(f"[{i+1}/{len(combinations)}] Testing: {params}")

        # ---------------------------------------------------------------------
        # TODO 14: Train model with current params and track best
        # ---------------------------------------------------------------------

        model, train_losses, val_losses = train_model(
            l1_lambda=params["l1_lambda"],
            l2_lambda=params["l2_lambda"],
            dropout_rate=params["dropout_rate"],
            weight_init="kaiming",
            lr=params["lr"]
        )

        current_val_loss = val_losses[-1]

        if current_val_loss < best_val_loss:
            best_val_loss = current_val_loss
            best_params = params
            best_model = copy.deepcopy(model)

            print(">>> NEW BEST MODEL FOUND <<<")

        print("-" * 60)

    print(f"Best Validation Loss: {best_val_loss:.4f}")
    print(f"Best Parameters: {best_params}")

    return best_model, best_params

# %%
# WARNING: This might take a long time! Only run if you have time to spare.
# Uncomment to run grid search:

# best_model_grid, best_params_grid = grid_search(param_grid)
# print("Testing best model from Grid Search:")
# test_model(best_model_grid)
param_grid = {
    "l1_lambda": [0.0, 0.0001],
    "l2_lambda": [0.001, 0.01],
    "dropout_rate": [0.2, 0.3],
    "weight_init": ["kaiming"],
    "lr": [0.001, 0.0005]
}

best_model, best_params = grid_search(param_grid)
# Out:
# Grid Search: Testing 16 combinations
#
# [1/16] Testing: {'l1_lambda': 0.0, 'l2_lambda': 0.001, 'dropout_rate': 0.2, 'lr': 0.001}
# Weights initialized using kaiming method
# ============================================================
# TRAINING STARTED
# ============================================================
# Epoch [ 1/100] | Train Loss: 1.9268 | Val Loss: 0.0066
# Checkpoint saved! (val_loss: 0.0066)
# Epoch [ 2/100] | Train Loss: 1.3642 | Val Loss: 0.0044
# Checkpoint saved! (val_loss: 0.0044)
# Epoch [ 3/100] | Train Loss: 1.1300 | Val Loss: 0.0035
# Checkpoint saved! (val_loss: 0.0035)
# Epoch [ 4/100] | Train Loss: 1.0082 | Val Loss: 0.0031
# Checkpoint saved! (val_loss: 0.0031)
# Epoch [ 5/100] | Train Loss: 0.9327 | Val Loss: 0.0028
# Checkpoint saved! (val_loss: 0.0028)
# Epoch [ 6/100] | Train Loss: 0.8803 | Val Loss: 0.0026
# Checkpoint saved! (val_loss: 0.0026)
# Epoch [ 7/100] | Train Loss: 0.8388 | Val Loss: 0.0025
# Checkpoint saved! (val_loss: 0.0025)
# Epoch [ 8/100] | Train Loss: 0.8038 | Val Loss: 0.0023
# Checkpoint saved! (val_loss: 0.0023)
# Epoch [ 9/100] | Train Loss: 0.7739 | Val Loss: 0.0022
# Checkpoint saved! (val_loss: 0.0022)
# Epoch [10/100] | Train Loss: 0.7570 | Val Loss: 0.0021
# Checkpoint saved! (val_loss: 0.0021)
# Epoch [11/100] | Train Loss: 0.7347 | Val Loss: 0.0020
# Checkpoint saved! (val_loss: 0.0020)
# Epoch [12/100] | Train Loss: 0.7169 | Val Loss: 0.0020
# Checkpoint saved! (val_loss: 0.0020)
# Epoch [13/100] | Train Loss: 0.7024 | Val Loss: 0.0019
# Checkpoint saved! (val_loss: 0.0019)
# Epoch [14/100] | Train Loss: 0.6889 | Val Loss: 0.0019
# EarlyStopping counter: 1/20
# Epoch [15/100] | Train Loss: 0.6751 | Val Loss: 0.0018
# Checkpoint saved! (val_loss: 0.0018)
# Epoch [16/100] | Train Loss: 0.6627 | Val Loss: 0.0017
# Checkpoint saved! (val_loss: 0.0017)
# Epoch [17/100] | Train Loss: 0.6525 | Val Loss: 0.0017
# Checkpoint saved! (val_loss: 0.0017)
# Epoch [18/100] | Train Loss: 0.6423 | Val Loss: 0.0017
# Checkpoint saved! (val_loss: 0.0017)
# Epoch [19/100] | Train Loss: 0.6312 | Val Loss: 0.0017
# Checkpoint saved! (val_loss: 0.0017)
# Epoch [20/100] | Train Loss: 0.6258 | Val Loss: 0.0017
# EarlyStopping counter: 1/20
# Epoch [21/100] | Train Loss: 0.6186 | Val Loss: 0.0016
# Checkpoint saved! (val_loss: 0.0016)
# Epoch [22/100] | Train Loss: 0.6114 | Val Loss: 0.0016
# Checkpoint saved! (val_loss: 0.0016)
# Epoch [23/100] | Train Loss: 0.6024 | Val Loss: 0.0015
# Checkpoint saved! (val_loss: 0.0015)
# Epoch [24/100] | Train Loss: 0.5988 | Val Loss: 0.0016
# EarlyStopping counter: 1/20
# Epoch [25/100] | Train Loss: 0.5966 | Val Loss: 0.0015
# Checkpoint saved! (val_loss: 0.0015)
# Epoch [26/100] | Train Loss: 0.5876 | Val Loss: 0.0015
# Checkpoint saved! (val_loss: 0.0015)
# Epoch [27/100] | Train Loss: 0.5817 | Val Loss: 0.0015
# Checkpoint saved! (val_loss: 0.0015)
# Epoch [28/100] | Train Loss: 0.5761 | Val Loss: 0.0015
# Checkpoint saved! (val_loss: 0.0015)
# Epoch [29/100] | Train Loss: 0.5727 | Val Loss: 0.0015
# Checkpoint saved! (val_loss: 0.0015)
# Epoch [30/100] | Train Loss: 0.5640 | Val Loss: 0.0014
# Checkpoint saved! (val_loss: 0.0014)
# Epoch [31/100] | Train Loss: 0.5624 | Val Loss: 0.0015
# EarlyStopping counter: 1/20
# Epoch [32/100] | Train Loss: 0.5593 | Val Loss: 0.0014
# EarlyStopping counter: 2/20
# Epoch [33/100] | Train Loss: 0.5545 | Val Loss: 0.0014
# Checkpoint saved! (val_loss: 0.0014)
# Epoch [34/100] | Train Loss: 0.5508 | Val Loss: 0.0014
# EarlyStopping counter: 1/20
# Epoch [35/100] | Train Loss: 0.5456 | Val Loss: 0.0014
# Checkpoint saved! (val_loss: 0.0014)
# Epoch [36/100] | Train Loss: 0.5423 | Val Loss: 0.0014
# EarlyStopping counter: 1/20
# Epoch [37/100] | Train Loss: 0.5416 | Val Loss: 0.0014
# EarlyStopping counter: 2/20
# Epoch [38/100] | Train Loss: 0.5368 | Val Loss: 0.0014
# Checkpoint saved! (val_loss: 0.0014)
# Epoch [39/100] | Train Loss: 0.5343 | Val Loss: 0.0014
# EarlyStopping counter: 1/20
# Epoch [40/100] | Train Loss: 0.5290 | Val Loss: 0.0014
# EarlyStopping counter: 2/20
# Epoch [41/100] | Train Loss: 0.5245 | Val Loss: 0.0014
# Checkpoint saved! (val_loss: 0.0014)
# Epoch [42/100] | Train Loss: 0.5255 | Val Loss: 0.0014
# EarlyStopping counter: 1/20
# Epoch [43/100] | Train Loss: 0.5200 | Val Loss: 0.0014
# EarlyStopping counter: 2/20
# Epoch [44/100] | Train Loss: 0.5190 | Val Loss: 0.0013
# Checkpoint saved! (val_loss: 0.0013)
# Epoch [45/100] | Train Loss: 0.5173 | Val Loss: 0.0013
# Checkpoint saved! (val_loss: 0.0013)
# Epoch [46/100] | Train Loss: 0.5128 | Val Loss: 0.0013
# EarlyStopping counter: 1/20
# Epoch [47/100] | Train Loss: 0.5122 | Val Loss: 0.0013
# EarlyStopping counter: 2/20
# Epoch [48/100] | Train Loss: 0.5099 | Val Loss: 0.0013
# Checkpoint saved! (val_loss: 0.0013)
# Epoch [49/100] | Train Loss: 0.5062 | Val Loss: 0.0013
# EarlyStopping counter: 1/20
# Epoch [50/100] | Train Loss: 0.5033 | Val Loss: 0.0013
# Checkpoint saved! (val_loss: 0.0013)
# Epoch [51/100] | Train Loss: 0.5025 | Val Loss: 0.0013
# EarlyStopping counter: 1/20
# Epoch [52/100] | Train Loss: 0.4995 | Val Loss: 0.0013
# Checkpoint saved! (val_loss: 0.0013)
# Epoch [53/100] | Train Loss: 0.4967 | Val Loss: 0.0013
# EarlyStopping counter: 1/20
# Epoch [54/100] | Train Loss: 0.4978 | Val Loss: 0.0013
# EarlyStopping counter: 2/20
# Epoch [55/100] | Train Loss: 0.4959 | Val Loss: 0.0013
# Checkpoint saved! (val_loss: 0.0013)
# Epoch [56/100] | Train Loss: 0.4920 | Val Loss: 0.0013
# EarlyStopping counter: 1/20
# Epoch [57/100] | Train Loss: 0.4875 | Val Loss: 0.0013
# EarlyStopping counter: 2/20
# Epoch [58/100] | Train Loss: 0.4892 | Val Loss: 0.0013
# EarlyStopping counter: 3/20
# Epoch [59/100] | Train Loss: 0.4858 | Val Loss: 0.0013
# Checkpoint saved! (val_loss: 0.0013)
# Epoch [60/100] | Train Loss: 0.4836 | Val Loss: 0.0012
# Checkpoint saved! (val_loss: 0.0012)
# Epoch [61/100] | Train Loss: 0.4832 | Val Loss: 0.0012
# Checkpoint saved! (val_loss: 0.0012)
# Epoch [62/100] | Train Loss: 0.4785 | Val Loss: 0.0012
# Checkpoint saved! (val_loss: 0.0012)
# Epoch [63/100] | Train Loss: 0.4780 | Val Loss: 0.0012
# EarlyStopping counter: 1/20
# Epoch [64/100] | Train Loss: 0.4789 | Val Loss: 0.0012
# Checkpoint saved! (val_loss: 0.0012)
# Epoch [65/100] | Train Loss: 0.4761 | Val Loss: 0.0012
# EarlyStopping counter: 1/20
# Epoch [66/100] | Train Loss: 0.4774 | Val Loss: 0.0012
# Checkpoint saved! (val_loss: 0.0012)
# Epoch [67/100] | Train Loss: 0.4740 | Val Loss: 0.0012
# EarlyStopping counter: 1/20
# Epoch [68/100] | Train Loss: 0.4710 | Val Loss: 0.0012
# Checkpoint saved! (val_loss: 0.0012)
# Epoch [69/100] | Train Loss: 0.4677 | Val Loss: 0.0012
# Checkpoint saved! (val_loss: 0.0012)
# Epoch [70/100] | Train Loss: 0.4686 | Val Loss: 0.0012
# EarlyStopping counter: 1/20
# Epoch [71/100] | Train Loss: 0.4666 | Val Loss: 0.0012
# EarlyStopping counter: 2/20
# Epoch [72/100] | Train Loss: 0.4655 | Val Loss: 0.0012
# EarlyStopping counter: 3/20
# Epoch [73/100] | Train Loss: 0.4617 | Val Loss: 0.0012
# EarlyStopping counter: 4/20
# Epoch [74/100] | Train Loss: 0.4594 | Val Loss: 0.0012
# EarlyStopping counter: 5/20
# Epoch [75/100] | Train Loss: 0.4617 | Val Loss: 0.0012
# Checkpoint saved! (val_loss: 0.0012)
# Epoch [76/100] | Train Loss: 0.4595 | Val Loss: 0.0011
# Checkpoint saved! (val_loss: 0.0011)
# Epoch [77/100] | Train Loss: 0.4595 | Val Loss: 0.0011
# Checkpoint saved! (val_loss: 0.0011)
# Epoch [78/100] | Train Loss: 0.4567 | Val Loss: 0.0011
# Checkpoint saved! (val_loss: 0.0011)
# Epoch [79/100] | Train Loss: 0.4544 | Val Loss: 0.0012
# EarlyStopping counter: 1/20
# Epoch [80/100] | Train Loss: 0.4552 | Val Loss: 0.0011
# Checkpoint saved! (val_loss: 0.0011)
# Epoch [81/100] | Train Loss: 0.4552 | Val Loss: 0.0011
# EarlyStopping counter: 1/20
# Epoch [82/100] | Train Loss: 0.4567 | Val Loss: 0.0011
# Checkpoint saved! (val_loss: 0.0011)
# Epoch [83/100] | Train Loss: 0.4511 | Val Loss: 0.0011
# EarlyStopping counter: 1/20
# Epoch [84/100] | Train Loss: 0.4497 | Val Loss: 0.0011
# Checkpoint saved! (val_loss: 0.0011)
# Epoch [85/100] | Train Loss: 0.4481 | Val Loss: 0.0011
# Checkpoint saved! (val_loss: 0.0011)
# Epoch [86/100] | Train Loss: 0.4465 | Val Loss: 0.0011
# EarlyStopping counter: 1/20
# Epoch [87/100] | Train Loss: 0.4483 | Val Loss: 0.0011
# EarlyStopping counter: 2/20
# Epoch [88/100] | Train Loss: 0.4461 | Val Loss: 0.0011
# EarlyStopping counter: 3/20
# Epoch [89/100] | Train Loss: 0.4451 | Val Loss: 0.0011
# EarlyStopping counter: 4/20
# Epoch [90/100] | Train Loss: 0.4437 | Val Loss: 0.0011
# Checkpoint saved! (val_loss: 0.0011)
# Epoch [91/100] | Train Loss: 0.4421 | Val Loss: 0.0011
# EarlyStopping counter: 1/20
# Epoch [92/100] | Train Loss: 0.4433 | Val Loss: 0.0011
# Checkpoint saved! (val_loss: 0.0011)
# Epoch [93/100] | Train Loss: 0.4375 | Val Loss: 0.0011
# EarlyStopping counter: 1/20
# Epoch [94/100] | Train Loss: 0.4380 | Val Loss: 0.0011
# Checkpoint saved! (val_loss: 0.0011)
# Epoch [95/100] | Train Loss: 0.4370 | Val Loss: 0.0011
# EarlyStopping counter: 1/20
# Epoch [96/100] | Train Loss: 0.4381 | Val Loss: 0.0011
# Checkpoint saved! (val_loss: 0.0011)
# Epoch [97/100] | Train Loss: 0.4331 | Val Loss: 0.0011
# Checkpoint saved! (val_loss: 0.0011)
# Epoch [98/100] | Train Loss: 0.4357 | Val Loss: 0.0011
# EarlyStopping counter: 1/20
# Epoch [99/100] | Train Loss: 0.4342 | Val Loss: 0.0011
# EarlyStopping counter: 2/20
# Epoch [100/100] | Train Loss: 0.4322 | Val Loss: 0.0010
# Checkpoint saved! (val_loss: 0.0010)
# ============================================================
# TRAINING COMPLETED
# Best validation loss: 0.0010
# ============================================================
# >>> NEW BEST MODEL FOUND <<<
# ------------------------------------------------------------
# [2/16] Testing: {'l1_lambda': 0.0, 'l2_lambda': 0.001, 'dropout_rate': 0.2, 'lr': 0.0005}
# Weights initialized using kaiming method
# ============================================================
# TRAINING STARTED
# ============================================================
# Epoch [ 1/100] | Train Loss: 2.0498 | Val Loss: 0.0086
# Checkpoint saved! (val_loss: 0.0086)
# Epoch [ 2/100] | Train Loss: 1.5917 | Val Loss: 0.0064
# Checkpoint saved! (val_loss: 0.0064)
# Epoch [ 3/100] | Train Loss: 1.3486 | Val Loss: 0.0052
# Checkpoint saved! (val_loss: 0.0052)
# Epoch [ 4/100] | Train Loss: 1.1995 | Val Loss: 0.0045
# Checkpoint saved! (val_loss: 0.0045)
# Epoch [ 5/100] | Train Loss: 1.1028 | Val Loss: 0.0040
# Checkpoint saved! (val_loss: 0.0040)
# Epoch [ 6/100] | Train Loss: 1.0351 | Val Loss: 0.0036
# Checkpoint saved! (val_loss: 0.0036)
# Epoch [ 7/100] | Train Loss: 0.9834 | Val Loss: 0.0034
# Checkpoint saved! (val_loss: 0.0034)
# Epoch [ 8/100] | Train Loss: 0.9391 | Val Loss: 0.0031
# Checkpoint saved! (val_loss: 0.0031)
# Epoch [ 9/100] | Train Loss: 0.9036 | Val Loss: 0.0030
# Checkpoint saved! (val_loss: 0.0030)
# Epoch [10/100] | Train Loss: 0.8755 | Val Loss: 0.0029
# Checkpoint saved! (val_loss: 0.0029)
# Epoch [11/100] | Train Loss: 0.8546 | Val Loss: 0.0028
# Checkpoint saved! (val_loss: 0.0028)
# Epoch [12/100] | Train Loss: 0.8297 | Val Loss: 0.0027
# Checkpoint saved! (val_loss: 0.0027)
# Epoch [13/100] | Train Loss: 0.8161 | Val Loss: 0.0026
# Checkpoint saved! (val_loss: 0.0026)
# Epoch [14/100] | Train Loss: 0.7959 | Val Loss: 0.0025
# Checkpoint saved! (val_loss: 0.0025)
# Epoch [15/100] | Train Loss: 0.7827 | Val Loss: 0.0024
# Checkpoint saved! (val_loss: 0.0024)
# Epoch [16/100] | Train Loss: 0.7682 | Val Loss: 0.0024
# Checkpoint saved! (val_loss: 0.0024)
# Epoch [17/100] | Train Loss: 0.7564 | Val Loss: 0.0023
# Checkpoint saved! (val_loss: 0.0023)
# Epoch [18/100] | Train Loss: 0.7453 | Val Loss: 0.0023
# Checkpoint saved! (val_loss: 0.0023)
# Epoch [19/100] | Train Loss: 0.7338 | Val Loss: 0.0022
# Checkpoint saved! (val_loss: 0.0022)
# Epoch [20/100] | Train Loss: 0.7258 | Val Loss: 0.0022
# Checkpoint saved! (val_loss: 0.0022)
# Epoch [21/100] | Train Loss: 0.7167 | Val Loss: 0.0021
# Checkpoint saved! (val_loss: 0.0021)
# Epoch [22/100] | Train Loss: 0.7065 | Val Loss: 0.0021
# Checkpoint saved! (val_loss: 0.0021)
# Epoch [23/100] | Train Loss: 0.6991 | Val Loss: 0.0020
# Checkpoint saved! (val_loss: 0.0020)
# Epoch [24/100] | Train Loss: 0.6906 | Val Loss: 0.0021
# EarlyStopping counter: 1/20
# Epoch [25/100] | Train Loss: 0.6839 | Val Loss: 0.0020
# Checkpoint saved! (val_loss: 0.0020)
# Epoch [26/100] | Train Loss: 0.6826 | Val Loss: 0.0020
# EarlyStopping counter: 1/20
# Epoch [27/100] | Train Loss: 0.6735 | Val Loss: 0.0020
# Checkpoint saved! (val_loss: 0.0020)
# Epoch [28/100] | Train Loss: 0.6659 | Val Loss: 0.0019
# Checkpoint saved! (val_loss: 0.0019)
# Epoch [29/100] | Train Loss: 0.6559 | Val Loss: 0.0019
# EarlyStopping counter: 1/20
# Epoch [30/100] | Train Loss: 0.6540 | Val Loss: 0.0019
# EarlyStopping counter: 2/20
# Epoch [31/100] | Train Loss: 0.6487 | Val Loss: 0.0019
# Checkpoint saved! (val_loss: 0.0019)
# Epoch [32/100] | Train Loss: 0.6431 | Val Loss: 0.0019
# Checkpoint saved! (val_loss: 0.0019)
# Epoch [33/100] | Train Loss: 0.6377 | Val Loss: 0.0019
# Checkpoint saved! (val_loss: 0.0019)
# Epoch [34/100] | Train Loss: 0.6320 | Val Loss: 0.0018
# Checkpoint saved! (val_loss: 0.0018)
# Epoch [35/100] | Train Loss: 0.6334 | Val Loss: 0.0018
# Checkpoint saved! (val_loss: 0.0018)
# Epoch [36/100] | Train Loss: 0.6267 | Val Loss: 0.0018
# Checkpoint saved! (val_loss: 0.0018)
# Epoch [37/100] | Train Loss: 0.6233 | Val Loss: 0.0018
# Checkpoint saved! (val_loss: 0.0018)
# Epoch [38/100] | Train Loss: 0.6178 | Val Loss: 0.0018
# Checkpoint saved! (val_loss: 0.0018)
# Epoch [39/100] | Train Loss: 0.6127 | Val Loss: 0.0018
# EarlyStopping counter: 1/20
# Epoch [40/100] | Train Loss: 0.6099 | Val Loss: 0.0017
# Checkpoint saved! (val_loss: 0.0017)
# Epoch [41/100] | Train Loss: 0.6068 | Val Loss: 0.0017
# Checkpoint saved! (val_loss: 0.0017)
# Epoch [42/100] | Train Loss: 0.6031 | Val Loss: 0.0017
# Checkpoint saved! (val_loss: 0.0017)
# Epoch [43/100] | Train Loss: 0.5989 | Val Loss: 0.0017
# EarlyStopping counter: 1/20
# Epoch [44/100] | Train Loss: 0.5966 | Val Loss: 0.0017
# EarlyStopping counter: 2/20
# Epoch [45/100] | Train Loss: 0.5921 | Val Loss: 0.0017
# Checkpoint saved! (val_loss: 0.0017)
# Epoch [46/100] | Train Loss: 0.5886 | Val Loss: 0.0017
# EarlyStopping counter: 1/20
# Epoch [47/100] | Train Loss: 0.5882 | Val Loss: 0.0017
# Checkpoint saved! (val_loss: 0.0017)
# Epoch [48/100] | Train Loss: 0.5829 | Val Loss: 0.0016
# Checkpoint saved! (val_loss: 0.0016)
# Epoch [49/100] | Train Loss: 0.5793 | Val Loss: 0.0016
# Checkpoint saved! (val_loss: 0.0016)
# Epoch [50/100] | Train Loss: 0.5763 | Val Loss: 0.0016
# EarlyStopping counter: 1/20
# Epoch [51/100] | Train Loss: 0.5781 | Val Loss: 0.0016
# Checkpoint saved! (val_loss: 0.0016)
# Epoch [52/100] | Train Loss: 0.5722 | Val Loss: 0.0016
# EarlyStopping counter: 1/20
# Epoch [53/100] | Train Loss: 0.5717 | Val Loss: 0.0016
# EarlyStopping counter: 2/20
# Epoch [54/100] | Train Loss: 0.5687 | Val Loss: 0.0016
# EarlyStopping counter: 3/20
# Epoch [55/100] | Train Loss: 0.5652 | Val Loss: 0.0016
# EarlyStopping counter: 4/20
# Epoch [56/100] | Train Loss: 0.5653 | Val Loss: 0.0016
# Checkpoint saved! (val_loss: 0.0016)
# Epoch [57/100] | Train Loss: 0.5631 | Val Loss: 0.0016
# EarlyStopping counter: 1/20
# Epoch [58/100] | Train Loss: 0.5566 | Val Loss: 0.0016
# Checkpoint saved! (val_loss: 0.0016)
# Epoch [59/100] | Train Loss: 0.5544 | Val Loss: 0.0016
# Checkpoint saved! (val_loss: 0.0016)
# Epoch [60/100] | Train Loss: 0.5538 | Val Loss: 0.0016
# Checkpoint saved! (val_loss: 0.0016)
# Epoch [61/100] | Train Loss: 0.5534 | Val Loss: 0.0016
# EarlyStopping counter: 1/20
# Epoch [62/100] | Train Loss: 0.5503 | Val Loss: 0.0016
# Checkpoint saved! (val_loss: 0.0016)
# Epoch [63/100] | Train Loss: 0.5492 | Val Loss: 0.0016
# EarlyStopping counter: 1/20
# Epoch [64/100] | Train Loss: 0.5472 | Val Loss: 0.0015
# Checkpoint saved! (val_loss: 0.0015)
# Epoch [65/100] | Train Loss: 0.5428 | Val Loss: 0.0016
# EarlyStopping counter: 1/20
# Epoch [66/100] | Train Loss: 0.5405 | Val Loss: 0.0016
# EarlyStopping counter: 2/20
# Epoch [67/100] | Train Loss: 0.5412 | Val Loss: 0.0015
# EarlyStopping counter: 3/20
# Epoch [68/100] | Train Loss: 0.5381 | Val Loss: 0.0015
# Checkpoint saved! (val_loss: 0.0015)
# Epoch [69/100] | Train Loss: 0.5385 | Val Loss: 0.0015
# Checkpoint saved! (val_loss: 0.0015)
# Epoch [70/100] | Train Loss: 0.5355 | Val Loss: 0.0015
# Checkpoint saved! (val_loss: 0.0015)
# Epoch [71/100] | Train Loss: 0.5318 | Val Loss: 0.0015
# Checkpoint saved! (val_loss: 0.0015)
# Epoch [72/100] | Train Loss: 0.5304 | Val Loss: 0.0015
# Checkpoint saved! (val_loss: 0.0015)
# Epoch [73/100] | Train Loss: 0.5292 | Val Loss: 0.0015
# EarlyStopping counter: 1/20
# Epoch [74/100] | Train Loss: 0.5278 | Val Loss: 0.0015
# EarlyStopping counter: 2/20
# Epoch [75/100] | Train Loss: 0.5266 | Val Loss: 0.0015
# EarlyStopping counter: 3/20
# Epoch [76/100] | Train Loss: 0.5258 | Val Loss: 0.0015
# EarlyStopping counter: 4/20
# Epoch [77/100] | Train Loss: 0.5215 | Val Loss: 0.0015
# EarlyStopping counter: 5/20
# Epoch [78/100] | Train Loss: 0.5215 | Val Loss: 0.0015
# Checkpoint saved! (val_loss: 0.0015)
# Epoch [79/100] | Train Loss: 0.5196 | Val Loss: 0.0015
# EarlyStopping counter: 1/20
# Epoch [80/100] | Train Loss: 0.5191 | Val Loss: 0.0015
# Checkpoint saved! (val_loss: 0.0015)
# Epoch [81/100] | Train Loss: 0.5170 | Val Loss: 0.0014
# Checkpoint saved! (val_loss: 0.0014)
# Epoch [82/100] | Train Loss: 0.5176 | Val Loss: 0.0015
# EarlyStopping counter: 1/20
# Epoch [83/100] | Train Loss: 0.5134 | Val Loss: 0.0015
# EarlyStopping counter: 2/20
# Epoch [84/100] | Train Loss: 0.5137 | Val Loss: 0.0015
# EarlyStopping counter: 3/20
# Epoch [85/100] | Train Loss: 0.5116 | Val Loss: 0.0015
# EarlyStopping counter: 4/20
# Epoch [86/100] | Train Loss: 0.5094 | Val Loss: 0.0015
# EarlyStopping counter: 5/20
# Epoch [87/100] | Train Loss: 0.5074 | Val Loss: 0.0015
# EarlyStopping counter: 6/20
# Epoch [88/100] | Train Loss: 0.5065 | Val Loss: 0.0015
# EarlyStopping counter: 7/20
# Epoch [89/100] | Train Loss: 0.5061 | Val Loss: 0.0014
# Checkpoint saved! (val_loss: 0.0014)
# Epoch [90/100] | Train Loss: 0.5026 | Val Loss: 0.0014
# Checkpoint saved! (val_loss: 0.0014)
# Epoch [91/100] | Train Loss: 0.5045 | Val Loss: 0.0014
# EarlyStopping counter: 1/20
# Epoch [92/100] | Train Loss: 0.5047 | Val Loss: 0.0014
# Checkpoint saved! (val_loss: 0.0014)
# Epoch [93/100] | Train Loss: 0.5006 | Val Loss: 0.0014
# Checkpoint saved! (val_loss: 0.0014)
# Epoch [94/100] | Train Loss: 0.5005 | Val Loss: 0.0014
# Checkpoint saved! (val_loss: 0.0014)
# Epoch [95/100] | Train Loss: 0.4976 | Val Loss: 0.0014
# Checkpoint saved! (val_loss: 0.0014)
# Epoch [96/100] | Train Loss: 0.4953 | Val Loss: 0.0014
# Checkpoint saved! (val_loss: 0.0014)
# Epoch [97/100] | Train Loss: 0.4956 | Val Loss: 0.0014
# EarlyStopping counter: 1/20
# Epoch [98/100] | Train Loss: 0.4945 | Val Loss: 0.0014
# EarlyStopping counter: 2/20
# Epoch [99/100] | Train Loss: 0.4927 | Val Loss: 0.0014
# EarlyStopping counter: 3/20
# Epoch [100/100] | Train Loss: 0.4915 | Val Loss: 0.0014
# EarlyStopping counter: 4/20
# ============================================================
# TRAINING COMPLETED
# Best validation loss: 0.0014
# ============================================================
# ------------------------------------------------------------
# [3/16] Testing: {'l1_lambda': 0.0, 'l2_lambda': 0.001, 'dropout_rate': 0.3, 'lr': 0.001}
# Weights initialized using kaiming method
# ============================================================
# TRAINING STARTED
# ============================================================
# Epoch [ 1/100] | Train Loss: 1.9893 | Val Loss: 0.0060
# Checkpoint saved! (val_loss: 0.0060)
# Epoch [ 2/100] | Train Loss: 1.4154 | Val Loss: 0.0042
# Checkpoint saved! (val_loss: 0.0042)
# Epoch [ 3/100] | Train Loss: 1.1886 | Val Loss: 0.0034
# Checkpoint saved! (val_loss: 0.0034)
# Epoch [ 4/100] | Train Loss: 1.0664 | Val Loss: 0.0030
# Checkpoint saved! (val_loss: 0.0030)
# Epoch [ 5/100] | Train Loss: 0.9849 | Val Loss: 0.0027
# Checkpoint saved! (val_loss: 0.0027)
# Epoch [ 6/100] | Train Loss: 0.9256 | Val Loss: 0.0025
# Checkpoint saved! (val_loss: 0.0025)
# Epoch [ 7/100] | Train Loss: 0.8824 | Val Loss: 0.0023
# Checkpoint saved! (val_loss: 0.0023)
# Epoch [ 8/100] | Train Loss: 0.8455 | Val Loss: 0.0021
# Checkpoint saved! (val_loss: 0.0021)
# Epoch [ 9/100] | Train Loss: 0.8236 | Val Loss: 0.0021
# Checkpoint saved! (val_loss: 0.0021)
# Epoch [10/100] | Train Loss: 0.7990 | Val Loss: 0.0020
# Checkpoint saved! (val_loss: 0.0020)
# Epoch [11/100] | Train Loss: 0.7735 | Val Loss: 0.0019
# Checkpoint saved! (val_loss: 0.0019)
# Epoch [12/100] | Train Loss: 0.7599 | Val Loss: 0.0018
# Checkpoint saved! (val_loss: 0.0018)
# Epoch [13/100] | Train Loss: 0.7435 | Val Loss: 0.0017
# Checkpoint saved! (val_loss: 0.0017)
# Epoch [14/100] | Train Loss: 0.7297 | Val Loss: 0.0017
# Checkpoint saved! (val_loss: 0.0017)
# Epoch [15/100] | Train Loss: 0.7147 | Val Loss: 0.0017
# Checkpoint saved! (val_loss: 0.0017)
# Epoch [16/100] | Train Loss: 0.7021 | Val Loss: 0.0016
# Checkpoint saved! (val_loss: 0.0016)
# Epoch [17/100] | Train Loss: 0.6943 | Val Loss: 0.0016
# Checkpoint saved! (val_loss: 0.0016)
# Epoch [18/100] | Train Loss: 0.6811 | Val Loss: 0.0015
# Checkpoint saved! (val_loss: 0.0015)
# Epoch [19/100] | Train Loss: 0.6733 | Val Loss: 0.0015
# Checkpoint saved! (val_loss: 0.0015)
# Epoch [20/100] | Train Loss: 0.6649 | Val Loss: 0.0015
# Checkpoint saved! (val_loss: 0.0015)
# Epoch [21/100] | Train Loss: 0.6580 | Val Loss: 0.0015
# EarlyStopping counter: 1/20
# Epoch [22/100] | Train Loss: 0.6489 | Val Loss: 0.0014
# Checkpoint saved! (val_loss: 0.0014)
# Epoch [23/100] | Train Loss: 0.6400 | Val Loss: 0.0014
# Checkpoint saved! (val_loss: 0.0014)
# Epoch [24/100] | Train Loss: 0.6363 | Val Loss: 0.0014
# Checkpoint saved! (val_loss: 0.0014)
# Epoch [25/100] | Train Loss: 0.6277 | Val Loss: 0.0014
# Checkpoint saved! (val_loss: 0.0014)
# Epoch [26/100] | Train Loss: 0.6234 | Val Loss: 0.0014
# Checkpoint saved! (val_loss: 0.0014)
# Epoch [27/100] | Train Loss: 0.6162 | Val Loss: 0.0013
# Checkpoint saved! (val_loss: 0.0013)
# Epoch [28/100] | Train Loss: 0.6119 | Val Loss: 0.0013
# Checkpoint saved! (val_loss: 0.0013)
# Epoch [29/100] | Train Loss: 0.6045 | Val Loss: 0.0013
# Checkpoint saved! (val_loss: 0.0013)
# Epoch [30/100] | Train Loss: 0.6014 | Val Loss: 0.0013
# EarlyStopping counter: 1/20
# Epoch [31/100] | Train Loss: 0.5945 | Val Loss: 0.0013
# Checkpoint saved! (val_loss: 0.0013)
# Epoch [32/100] | Train Loss: 0.5919 | Val Loss: 0.0013
# Checkpoint saved! (val_loss: 0.0013)
# Epoch [33/100] | Train Loss: 0.5864 | Val Loss: 0.0013
# Checkpoint saved! (val_loss: 0.0013)
# Epoch [34/100] | Train Loss: 0.5815 | Val Loss: 0.0013
# EarlyStopping counter: 1/20
# Epoch [35/100] | Train Loss: 0.5769 | Val Loss: 0.0012
# Checkpoint saved! (val_loss: 0.0012)
# Epoch [36/100] | Train Loss: 0.5769 | Val Loss: 0.0012
# EarlyStopping counter: 1/20
# Epoch [37/100] | Train Loss: 0.5705 | Val Loss: 0.0012
# Checkpoint saved! (val_loss: 0.0012)
# Epoch [38/100] | Train Loss: 0.5688 | Val Loss: 0.0012
# Checkpoint saved! (val_loss: 0.0012)
# Epoch [39/100] | Train Loss: 0.5619 | Val Loss: 0.0012
# Checkpoint saved! (val_loss: 0.0012)
# Epoch [40/100] | Train Loss: 0.5597 | Val Loss: 0.0012
# EarlyStopping counter: 1/20
# Epoch [41/100] | Train Loss: 0.5585 | Val Loss: 0.0012
# Checkpoint saved! (val_loss: 0.0012)
# Epoch [42/100] | Train Loss: 0.5515 | Val Loss: 0.0012
# EarlyStopping counter: 1/20
# Epoch [43/100] | Train Loss: 0.5547 | Val Loss: 0.0012
# Checkpoint saved! (val_loss: 0.0012)
# Epoch [44/100] | Train Loss: 0.5496 | Val Loss: 0.0011
# Checkpoint saved! (val_loss: 0.0011)
# Epoch [45/100] | Train Loss: 0.5462 | Val Loss: 0.0012
# EarlyStopping counter: 1/20
# Epoch [46/100] | Train Loss: 0.5419 | Val Loss: 0.0011
# Checkpoint saved! (val_loss: 0.0011)
# Epoch [47/100] | Train Loss: 0.5378 | Val Loss: 0.0011
# EarlyStopping counter: 1/20
# Epoch [48/100] | Train Loss: 0.5384 | Val Loss: 0.0011
# Checkpoint saved! (val_loss: 0.0011)
# Epoch [49/100] | Train Loss: 0.5333 | Val Loss: 0.0011
# Checkpoint saved! (val_loss: 0.0011)
# Epoch [50/100] | Train Loss: 0.5313 | Val Loss: 0.0011
# EarlyStopping counter: 1/20
# Epoch [51/100] | Train Loss: 0.5258 | Val Loss: 0.0011
# Checkpoint saved! (val_loss: 0.0011)
# Epoch [52/100] | Train Loss: 0.5287 | Val Loss: 0.0011
# Checkpoint saved! (val_loss: 0.0011)
# Epoch [53/100] | Train Loss: 0.5239 | Val Loss: 0.0011
# EarlyStopping counter: 1/20
# Epoch [54/100] | Train Loss: 0.5218 | Val Loss: 0.0011
# Checkpoint saved! (val_loss: 0.0011)
# Epoch [55/100] | Train Loss: 0.5184 | Val Loss: 0.0010
# Checkpoint saved! (val_loss: 0.0010)
# Epoch [56/100] | Train Loss: 0.5162 | Val Loss: 0.0011
# EarlyStopping counter: 1/20
# Epoch [57/100] | Train Loss: 0.5143 | Val Loss: 0.0011
# EarlyStopping counter: 2/20
# Epoch [58/100] | Train Loss: 0.5124 | Val Loss: 0.0010
# Checkpoint saved! (val_loss: 0.0010)
# Epoch [59/100] | Train Loss: 0.5091 | Val Loss: 0.0011
# EarlyStopping counter: 1/20
# Epoch [60/100] | Train Loss: 0.5120 | Val Loss: 0.0010
# Checkpoint saved! (val_loss: 0.0010)
# Epoch [61/100] | Train Loss: 0.5063 | Val Loss: 0.0010
# Checkpoint saved! (val_loss: 0.0010)
# Epoch [62/100] | Train Loss: 0.5035 | Val Loss: 0.0010
# EarlyStopping counter: 1/20
# Epoch [63/100] | Train Loss: 0.5026 | Val Loss: 0.0010
# EarlyStopping counter: 2/20
# Epoch [64/100] | Train Loss: 0.5035 | Val Loss: 0.0010
# Checkpoint saved! (val_loss: 0.0010)
# Epoch [65/100] | Train Loss: 0.5000 | Val Loss: 0.0010
# Checkpoint saved! (val_loss: 0.0010)
# Epoch [66/100] | Train Loss: 0.4981 | Val Loss: 0.0010
# EarlyStopping counter: 1/20
# Epoch [67/100] | Train Loss: 0.4967 | Val Loss: 0.0010
# Checkpoint saved! (val_loss: 0.0010)
# Epoch [68/100] | Train Loss: 0.4954 | Val Loss: 0.0010
# Checkpoint saved! (val_loss: 0.0010)
# Epoch [69/100] | Train Loss: 0.4900 | Val Loss: 0.0010
# Checkpoint saved! (val_loss: 0.0010)
# Epoch [70/100] | Train Loss: 0.4924 | Val Loss: 0.0010
# Checkpoint saved! (val_loss: 0.0010)
# Epoch [71/100] | Train Loss: 0.4878 | Val Loss: 0.0010
# Checkpoint saved! (val_loss: 0.0010)
# Epoch [72/100] | Train Loss: 0.4876 | Val Loss: 0.0009
# Checkpoint saved! (val_loss: 0.0009)
# Epoch [73/100] | Train Loss: 0.4829 | Val Loss: 0.0009
# Checkpoint saved! (val_loss: 0.0009)
# Epoch [74/100] | Train Loss: 0.4842 | Val Loss: 0.0009
# EarlyStopping counter: 1/20
# Epoch [75/100] | Train Loss: 0.4853 | Val Loss: 0.0010
# EarlyStopping counter: 2/20
# Epoch [76/100] | Train Loss: 0.4836 | Val Loss: 0.0009
# EarlyStopping counter: 3/20
# Epoch [77/100] | Train Loss: 0.4784 | Val Loss: 0.0010
# EarlyStopping counter: 4/20
# Epoch [78/100] | Train Loss: 0.4791 | Val Loss: 0.0009
# Checkpoint saved! (val_loss: 0.0009)
# Epoch [79/100] | Train Loss: 0.4743 | Val Loss: 0.0009
# EarlyStopping counter: 1/20
# Epoch [80/100] | Train Loss: 0.4787 | Val Loss: 0.0009
# Checkpoint saved! (val_loss: 0.0009)
# Epoch [81/100] | Train Loss: 0.4763 | Val Loss: 0.0009
# EarlyStopping counter: 1/20
# Epoch [82/100] | Train Loss: 0.4725 | Val Loss: 0.0009
# EarlyStopping counter: 2/20
# Epoch [83/100] | Train Loss: 0.4709 | Val Loss: 0.0009
# EarlyStopping counter: 3/20
# Epoch [84/100] | Train Loss: 0.4698 | Val Loss: 0.0009
# Checkpoint saved! (val_loss: 0.0009)
# Epoch [85/100] | Train Loss: 0.4695 | Val Loss: 0.0009
# Checkpoint saved! (val_loss: 0.0009)
# Epoch [86/100] | Train Loss: 0.4664 | Val Loss: 0.0009
# Checkpoint saved! (val_loss: 0.0009)
# Epoch [87/100] | Train Loss: 0.4665 | Val Loss: 0.0009
# Checkpoint saved! (val_loss: 0.0009)
# Epoch [88/100] | Train Loss: 0.4654 | Val Loss: 0.0009
# EarlyStopping counter: 1/20
# Epoch [89/100] | Train Loss: 0.4636 | Val Loss: 0.0009
# Checkpoint saved! (val_loss: 0.0009)
# Epoch [90/100] | Train Loss: 0.4643 | Val Loss: 0.0009
# EarlyStopping counter: 1/20
# Epoch [91/100] | Train Loss: 0.4596 | Val Loss: 0.0009
# EarlyStopping counter: 2/20
# Epoch [92/100] | Train Loss: 0.4601 | Val Loss: 0.0009
# EarlyStopping counter: 3/20
# Epoch [93/100] | Train Loss: 0.4605 | Val Loss: 0.0009
# EarlyStopping counter: 4/20
# Epoch [94/100] | Train Loss: 0.4615 | Val Loss: 0.0009
# Checkpoint saved! (val_loss: 0.0009)
# Epoch [95/100] | Train Loss: 0.4569 | Val Loss: 0.0009
# EarlyStopping counter: 1/20
# Epoch [96/100] | Train Loss: 0.4584 | Val Loss: 0.0009
# EarlyStopping counter: 2/20
# Epoch [97/100] | Train Loss: 0.4580 | Val Loss: 0.0009
# Checkpoint saved! (val_loss: 0.0009)
# Epoch [98/100] | Train Loss: 0.4574 | Val Loss: 0.0009
# EarlyStopping counter: 1/20
# Epoch [99/100] | Train Loss: 0.4541 | Val Loss: 0.0009
# EarlyStopping counter: 2/20
# Epoch [100/100] | Train Loss: 0.4540 | Val Loss: 0.0009
# Checkpoint saved! (val_loss: 0.0009)
# ============================================================
# TRAINING COMPLETED
# Best validation loss: 0.0009
# ============================================================
# >>> NEW BEST MODEL FOUND <<<
# ------------------------------------------------------------
# [4/16] Testing: {'l1_lambda': 0.0, 'l2_lambda': 0.001, 'dropout_rate': 0.3, 'lr': 0.0005}
# Weights initialized using kaiming method
# ============================================================
# TRAINING STARTED
# ============================================================
# Epoch [ 1/100] | Train Loss: 2.1482 | Val Loss: 0.0084
# Checkpoint saved! (val_loss: 0.0084)
# Epoch [ 2/100] | Train Loss: 1.7106 | Val Loss: 0.0064
# Checkpoint saved! (val_loss: 0.0064)
# Epoch [ 3/100] | Train Loss: 1.4800 | Val Loss: 0.0053
# Checkpoint saved! (val_loss: 0.0053)
# Epoch [ 4/100] | Train Loss: 1.3365 | Val Loss: 0.0046
# Checkpoint saved! (val_loss: 0.0046)
# Epoch [ 5/100] | Train Loss: 1.2324 | Val Loss: 0.0042
# Checkpoint saved! (val_loss: 0.0042)
# Epoch [ 6/100] | Train Loss: 1.1594 | Val Loss: 0.0038
# Checkpoint saved! (val_loss: 0.0038)
# Epoch [ 7/100] | Train Loss: 1.0988 | Val Loss: 0.0036
# Checkpoint saved! (val_loss: 0.0036)
# Epoch [ 8/100] | Train Loss: 1.0562 | Val Loss: 0.0034
# Checkpoint saved! (val_loss: 0.0034)
# Epoch [ 9/100] | Train Loss: 1.0106 | Val Loss: 0.0032
# Checkpoint saved! (val_loss: 0.0032)
# Epoch [10/100] | Train Loss: 0.9847 | Val Loss: 0.0031
# Checkpoint saved! (val_loss: 0.0031)
# Epoch [11/100] | Train Loss: 0.9556 | Val Loss: 0.0030
# Checkpoint saved! (val_loss: 0.0030)
# Epoch [12/100] | Train Loss: 0.9282 | Val Loss: 0.0029
# Checkpoint saved! (val_loss: 0.0029)
# Epoch [13/100] | Train Loss: 0.9086 | Val Loss: 0.0028
# Checkpoint saved! (val_loss: 0.0028)
# Epoch [14/100] | Train Loss: 0.8913 | Val Loss: 0.0027
# Checkpoint saved! (val_loss: 0.0027)
# Epoch [15/100] | Train Loss: 0.8718 | Val Loss: 0.0026
# Checkpoint saved! (val_loss: 0.0026)
# Epoch [16/100] | Train Loss: 0.8597 | Val Loss: 0.0025
# Checkpoint saved! (val_loss: 0.0025)
# Epoch [17/100] | Train Loss: 0.8422 | Val Loss: 0.0024
# Checkpoint saved! (val_loss: 0.0024)
# Epoch [18/100] | Train Loss: 0.8281 | Val Loss: 0.0024
# Checkpoint saved! (val_loss: 0.0024)
# Epoch [19/100] | Train Loss: 0.8169 | Val Loss: 0.0023
# Checkpoint saved! (val_loss: 0.0023)
# Epoch [20/100] | Train Loss: 0.8067 | Val Loss: 0.0023
# Checkpoint saved! (val_loss: 0.0023)
# Epoch [21/100] | Train Loss: 0.7924 | Val Loss: 0.0023
# Checkpoint saved! (val_loss: 0.0023)
# Epoch [22/100] | Train Loss: 0.7875 | Val Loss: 0.0022
# Checkpoint saved! (val_loss: 0.0022)
# Epoch [23/100] | Train Loss: 0.7760 | Val Loss: 0.0021
# Checkpoint saved! (val_loss: 0.0021)
# Epoch [24/100] | Train Loss: 0.7653 | Val Loss: 0.0021
# Checkpoint saved! (val_loss: 0.0021)
# Epoch [25/100] | Train Loss: 0.7545 | Val Loss: 0.0021
# Checkpoint saved! (val_loss: 0.0021)
# Epoch [26/100] | Train Loss: 0.7518 | Val Loss: 0.0020
# Checkpoint saved! (val_loss: 0.0020)
# Epoch [27/100] | Train Loss: 0.7413 | Val Loss: 0.0020
# Checkpoint saved! (val_loss: 0.0020)
# Epoch [28/100] | Train Loss: 0.7385 | Val Loss: 0.0020
# Checkpoint saved! (val_loss: 0.0020)
# Epoch [29/100] | Train Loss: 0.7331 | Val Loss: 0.0020
# Checkpoint saved! (val_loss: 0.0020)
# Epoch [30/100] | Train Loss: 0.7197 | Val Loss: 0.0019
# Checkpoint saved! (val_loss: 0.0019)
# Epoch [31/100] | Train Loss: 0.7156 | Val Loss: 0.0019
# Checkpoint saved! (val_loss: 0.0019)
# Epoch [32/100] | Train Loss: 0.7118 | Val Loss: 0.0019
# Checkpoint saved! (val_loss: 0.0019)
# Epoch [33/100] | Train Loss: 0.7038 | Val Loss: 0.0019
# Checkpoint saved! (val_loss: 0.0019)
# Epoch [34/100] | Train Loss: 0.6972 | Val Loss: 0.0018
# Checkpoint saved! (val_loss: 0.0018)
# Epoch [35/100] | Train Loss: 0.6941 | Val Loss: 0.0018
# Checkpoint saved! (val_loss: 0.0018)
# Epoch [36/100] | Train Loss: 0.6867 | Val Loss: 0.0018
# Checkpoint saved! (val_loss: 0.0018)
# Epoch [37/100] | Train Loss: 0.6837 | Val Loss: 0.0018
# Checkpoint saved! (val_loss: 0.0018)
# Epoch [38/100] | Train Loss: 0.6767 | Val Loss: 0.0017
# Checkpoint saved! (val_loss: 0.0017)
# Epoch [39/100] | Train Loss: 0.6742 | Val Loss: 0.0017
# Checkpoint saved! (val_loss: 0.0017)
# Epoch [40/100] | Train Loss: 0.6679 | Val Loss: 0.0017
# Checkpoint saved! (val_loss: 0.0017)
# Epoch [41/100] | Train Loss: 0.6659 | Val Loss: 0.0017
# Checkpoint saved! (val_loss: 0.0017)
# Epoch [42/100] | Train Loss: 0.6635 | Val Loss: 0.0017
# Checkpoint saved! (val_loss: 0.0017)
# Epoch [43/100] | Train Loss: 0.6572 | Val Loss: 0.0017
# EarlyStopping counter: 1/20
# Epoch [44/100] | Train Loss: 0.6528 | Val Loss: 0.0017
# Checkpoint saved! (val_loss: 0.0017)
# Epoch [45/100] | Train Loss: 0.6474 | Val Loss: 0.0016
# Checkpoint saved! (val_loss: 0.0016)
# Epoch [46/100] | Train Loss: 0.6424 | Val Loss: 0.0016
# Checkpoint saved! (val_loss: 0.0016)
# Epoch [47/100] | Train Loss: 0.6416 | Val Loss: 0.0016
# Checkpoint saved! (val_loss: 0.0016)
# Epoch [48/100] | Train Loss: 0.6404 | Val Loss: 0.0016
# Checkpoint saved! (val_loss: 0.0016)
# Epoch [49/100] | Train Loss: 0.6328 | Val Loss: 0.0016
# Checkpoint saved! (val_loss: 0.0016)
# Epoch [50/100] | Train Loss: 0.6313 | Val Loss: 0.0016
# EarlyStopping counter: 1/20
# Epoch [51/100] | Train Loss: 0.6300 | Val Loss: 0.0016
# Checkpoint saved! (val_loss: 0.0016)
# Epoch [52/100] | Train Loss: 0.6242 | Val Loss: 0.0015
# Checkpoint saved! (val_loss: 0.0015)
# Epoch [53/100] | Train Loss: 0.6218 | Val Loss: 0.0015
# Checkpoint saved! (val_loss: 0.0015)
# Epoch [54/100] | Train Loss: 0.6188 | Val Loss: 0.0015
# Checkpoint saved! (val_loss: 0.0015)
# Epoch [55/100] | Train Loss: 0.6188 | Val Loss: 0.0015
# EarlyStopping counter: 1/20
# Epoch [56/100] | Train Loss: 0.6129 | Val Loss: 0.0015
# Checkpoint saved! (val_loss: 0.0015)
# Epoch [57/100] | Train Loss: 0.6107 | Val Loss: 0.0015
# Checkpoint saved! (val_loss: 0.0015)
# Epoch [58/100] | Train Loss: 0.6078 | Val Loss: 0.0015
# Checkpoint saved! (val_loss: 0.0015)
# Epoch [59/100] | Train Loss: 0.6022 | Val Loss: 0.0015
# EarlyStopping counter: 1/20
# Epoch [60/100] | Train Loss: 0.5987 | Val Loss: 0.0015
# Checkpoint saved! (val_loss: 0.0015)
# Epoch [61/100] | Train Loss: 0.6024 | Val Loss: 0.0015
# EarlyStopping counter: 1/20
# Epoch [62/100] | Train Loss: 0.5982 | Val Loss: 0.0014
# Checkpoint saved! (val_loss: 0.0014)
# Epoch [63/100] | Train Loss: 0.5969 | Val Loss: 0.0014
# Checkpoint saved! (val_loss: 0.0014)
# Epoch [64/100] | Train Loss: 0.5938 | Val Loss: 0.0014
# EarlyStopping counter: 1/20
# Epoch [65/100] | Train Loss: 0.5922 | Val Loss: 0.0014
# Checkpoint saved! (val_loss: 0.0014)
# Epoch [66/100] | Train Loss: 0.5896 | Val Loss: 0.0014
# Checkpoint saved! (val_loss: 0.0014)
# Epoch [67/100] | Train Loss: 0.5860 | Val Loss: 0.0014
# Checkpoint saved! (val_loss: 0.0014)
# Epoch [68/100] | Train Loss: 0.5823 | Val Loss: 0.0014
# EarlyStopping counter: 1/20
# Epoch [69/100] | Train Loss: 0.5822 | Val Loss: 0.0014
# EarlyStopping counter: 2/20
# Epoch [70/100] | Train Loss: 0.5788 | Val Loss: 0.0014
# Checkpoint saved! (val_loss: 0.0014)
# Epoch [71/100] | Train Loss: 0.5780 | Val Loss: 0.0014
# Checkpoint saved! (val_loss: 0.0014)
# Epoch [72/100] | Train Loss: 0.5743 | Val Loss: 0.0014
# EarlyStopping counter: 1/20
# Epoch [73/100] | Train Loss: 0.5744 | Val Loss: 0.0014
# Checkpoint saved! (val_loss: 0.0014)
# Epoch [74/100] | Train Loss: 0.5726 | Val Loss: 0.0014
# EarlyStopping counter: 1/20
# Epoch [75/100] | Train Loss: 0.5711 | Val Loss: 0.0014
# Checkpoint saved! (val_loss: 0.0014)
# Epoch [76/100] | Train Loss: 0.5697 | Val Loss: 0.0013
# Checkpoint saved! (val_loss: 0.0013)
# Epoch [77/100] | Train Loss: 0.5662 | Val Loss: 0.0014
# EarlyStopping counter: 1/20
# Epoch [78/100] | Train Loss: 0.5643 | Val Loss: 0.0013
# Checkpoint saved! (val_loss: 0.0013)
# Epoch [79/100] | Train Loss: 0.5612 | Val Loss: 0.0013
# Checkpoint saved! (val_loss: 0.0013)
# Epoch [80/100] | Train Loss: 0.5610 | Val Loss: 0.0013
# EarlyStopping counter: 1/20
# Epoch [81/100] | Train Loss: 0.5578 | Val Loss: 0.0013
# Checkpoint saved! (val_loss: 0.0013)
# Epoch [82/100] | Train Loss: 0.5579 | Val Loss: 0.0013
# Checkpoint saved! (val_loss: 0.0013)
# Epoch [83/100] | Train Loss: 0.5574 | Val Loss: 0.0013
# EarlyStopping counter: 1/20
# Epoch [84/100] | Train Loss: 0.5550 | Val Loss: 0.0013
# Checkpoint saved! (val_loss: 0.0013)
# Epoch [85/100] | Train Loss: 0.5540 | Val Loss: 0.0013
# Checkpoint saved! (val_loss: 0.0013)
# Epoch [86/100] | Train Loss: 0.5496 | Val Loss: 0.0013
# EarlyStopping counter: 1/20
# Epoch [87/100] | Train Loss: 0.5497 | Val Loss: 0.0013
# EarlyStopping counter: 2/20
# Epoch [88/100] | Train Loss: 0.5488 | Val Loss: 0.0013
# Checkpoint saved! (val_loss: 0.0013)
# Epoch [89/100] | Train Loss: 0.5454 | Val Loss: 0.0013
# EarlyStopping counter: 1/20
# Epoch [90/100] | Train Loss: 0.5414 | Val Loss: 0.0013
# EarlyStopping counter: 2/20
# Epoch [91/100] | Train Loss: 0.5434 | Val Loss: 0.0013
# Checkpoint saved! (val_loss: 0.0013)
# Epoch [92/100] | Train Loss: 0.5409 | Val Loss: 0.0013
# Checkpoint saved! (val_loss: 0.0013)
# Epoch [93/100] | Train Loss: 0.5403 | Val Loss: 0.0013
# Checkpoint saved! (val_loss: 0.0013)
# Epoch [94/100] | Train Loss: 0.5372 | Val Loss: 0.0013
# Checkpoint saved! (val_loss: 0.0013)
# Epoch [95/100] | Train Loss: 0.5390 | Val Loss: 0.0013
# EarlyStopping counter: 1/20
# Epoch [96/100] | Train Loss: 0.5379 | Val Loss: 0.0013
# EarlyStopping counter: 2/20
# Epoch [97/100] | Train Loss: 0.5360 | Val Loss: 0.0013
# Checkpoint saved! (val_loss: 0.0013)
# Epoch [98/100] | Train Loss: 0.5333 | Val Loss: 0.0013
# Checkpoint saved! (val_loss: 0.0013)
# Epoch [99/100] | Train Loss: 0.5310 | Val Loss: 0.0013
# EarlyStopping counter: 1/20
# Epoch [100/100] | Train Loss: 0.5301 | Val Loss: 0.0013
# EarlyStopping counter: 2/20
# ============================================================
# TRAINING COMPLETED
# Best validation loss: 0.0013
# ============================================================
# ------------------------------------------------------------
# [5/16] Testing: {'l1_lambda': 0.0, 'l2_lambda': 0.01, 'dropout_rate': 0.2, 'lr': 0.001}
# Weights initialized using kaiming method
# ============================================================
# TRAINING STARTED
# ============================================================
# Epoch [ 1/100] | Train Loss: 1.8060 | Val Loss: 0.0059
# Checkpoint saved! (val_loss: 0.0059)
# Epoch [ 2/100] | Train Loss: 1.2575 | Val Loss: 0.0042
# Checkpoint saved! (val_loss: 0.0042)
# Epoch [ 3/100] | Train Loss: 1.0678 | Val Loss: 0.0035
# Checkpoint saved! (val_loss: 0.0035)
# Epoch [ 4/100] | Train Loss: 0.9678 | Val Loss: 0.0030
# Checkpoint saved! (val_loss: 0.0030)
# Epoch [ 5/100] | Train Loss: 0.8994 | Val Loss: 0.0027
# Checkpoint saved! (val_loss: 0.0027)
# Epoch [ 6/100] | Train Loss: 0.8562 | Val Loss: 0.0026
# Checkpoint saved! (val_loss: 0.0026)
# Epoch [ 7/100] | Train Loss: 0.8215 | Val Loss: 0.0024
# Checkpoint saved! (val_loss: 0.0024)
# Epoch [ 8/100] | Train Loss: 0.7956 | Val Loss: 0.0024
# Checkpoint saved! (val_loss: 0.0024)
# Epoch [ 9/100] | Train Loss: 0.7673 | Val Loss: 0.0022
# Checkpoint saved! (val_loss: 0.0022)
# Epoch [10/100] | Train Loss: 0.7495 | Val Loss: 0.0022
# Checkpoint saved! (val_loss: 0.0022)
# Epoch [11/100] | Train Loss: 0.7338 | Val Loss: 0.0021
# Checkpoint saved! (val_loss: 0.0021)
# Epoch [12/100] | Train Loss: 0.7173 | Val Loss: 0.0020
# Checkpoint saved! (val_loss: 0.0020)
# Epoch [13/100] | Train Loss: 0.7026 | Val Loss: 0.0020
# Checkpoint saved! (val_loss: 0.0020)
# Epoch [14/100] | Train Loss: 0.6918 | Val Loss: 0.0019
# Checkpoint saved! (val_loss: 0.0019)
# Epoch [15/100] | Train Loss: 0.6847 | Val Loss: 0.0019
# Checkpoint saved! (val_loss: 0.0019)
# Epoch [16/100] | Train Loss: 0.6728 | Val Loss: 0.0019
# Checkpoint saved! (val_loss: 0.0019)
# Epoch [17/100] | Train Loss: 0.6630 | Val Loss: 0.0018
# Checkpoint saved! (val_loss: 0.0018)
# Epoch [18/100] | Train Loss: 0.6561 | Val Loss: 0.0018
# Checkpoint saved! (val_loss: 0.0018)
# Epoch [19/100] | Train Loss: 0.6472 | Val Loss: 0.0018
# Checkpoint saved! (val_loss: 0.0018)
# Epoch [20/100] | Train Loss: 0.6437 | Val Loss: 0.0018
# Checkpoint saved! (val_loss: 0.0018)
# Epoch [21/100] | Train Loss: 0.6357 | Val Loss: 0.0018
# Checkpoint saved! (val_loss: 0.0018)
# Epoch [22/100] | Train Loss: 0.6301 | Val Loss: 0.0017
# Checkpoint saved! (val_loss: 0.0017)
# Epoch [23/100] | Train Loss: 0.6232 | Val Loss: 0.0017
# Checkpoint saved! (val_loss: 0.0017)
# Epoch [24/100] | Train Loss: 0.6183 | Val Loss: 0.0017
# EarlyStopping counter: 1/20
# Epoch [25/100] | Train Loss: 0.6128 | Val Loss: 0.0017
# EarlyStopping counter: 2/20
# Epoch [26/100] | Train Loss: 0.6087 | Val Loss: 0.0017
# Checkpoint saved! (val_loss: 0.0017)
# Epoch [27/100] | Train Loss: 0.6036 | Val Loss: 0.0016
# Checkpoint saved! (val_loss: 0.0016)
# Epoch [28/100] | Train Loss: 0.6011 | Val Loss: 0.0017
# EarlyStopping counter: 1/20
# Epoch [29/100] | Train Loss: 0.5958 | Val Loss: 0.0016
# Checkpoint saved! (val_loss: 0.0016)
# Epoch [30/100] | Train Loss: 0.5930 | Val Loss: 0.0016
# Checkpoint saved! (val_loss: 0.0016)
# Epoch [31/100] | Train Loss: 0.5898 | Val Loss: 0.0016
# Checkpoint saved! (val_loss: 0.0016)
# Epoch [32/100] | Train Loss: 0.5852 | Val Loss: 0.0016
# Checkpoint saved! (val_loss: 0.0016)
# Epoch [33/100] | Train Loss: 0.5833 | Val Loss: 0.0016
# EarlyStopping counter: 1/20
# Epoch [34/100] | Train Loss: 0.5795 | Val Loss: 0.0016
# Checkpoint saved! (val_loss: 0.0016)
# Epoch [35/100] | Train Loss: 0.5751 | Val Loss: 0.0016
# Checkpoint saved! (val_loss: 0.0016)
# Epoch [36/100] | Train Loss: 0.5724 | Val Loss: 0.0016
# Checkpoint saved! (val_loss: 0.0016)
# Epoch [37/100] | Train Loss: 0.5702 | Val Loss: 0.0015
# Checkpoint saved! (val_loss: 0.0015)
# Epoch [38/100] | Train Loss: 0.5697 | Val Loss: 0.0015
# Checkpoint saved! (val_loss: 0.0015)
# Epoch [39/100] | Train Loss: 0.5644 | Val Loss: 0.0015
# Checkpoint saved! (val_loss: 0.0015)
# Epoch [40/100] | Train Loss: 0.5626 | Val Loss: 0.0015
# EarlyStopping counter: 1/20
# Epoch [41/100] | Train Loss: 0.5628 | Val Loss: 0.0016
# EarlyStopping counter: 2/20
# Epoch [42/100] | Train Loss: 0.5591 | Val Loss: 0.0015
# EarlyStopping counter: 3/20
# Epoch [43/100] | Train Loss: 0.5580 | Val Loss: 0.0015
# EarlyStopping counter: 4/20
# Epoch [44/100] | Train Loss: 0.5554 | Val Loss: 0.0015
# EarlyStopping counter: 5/20
# Epoch [45/100] | Train Loss: 0.5519 | Val Loss: 0.0015
# Checkpoint saved! (val_loss: 0.0015)
# Epoch [46/100] | Train Loss: 0.5510 | Val Loss: 0.0015
# EarlyStopping counter: 1/20
# Epoch [47/100] | Train Loss: 0.5492 | Val Loss: 0.0015
# EarlyStopping counter: 2/20
# Epoch [48/100] | Train Loss: 0.5457 | Val Loss: 0.0015
# EarlyStopping counter: 3/20
# Epoch [49/100] | Train Loss: 0.5476 | Val Loss: 0.0015
# EarlyStopping counter: 4/20
# Epoch [50/100] | Train Loss: 0.5435 | Val Loss: 0.0015
# Checkpoint saved! (val_loss: 0.0015)
# Epoch [51/100] | Train Loss: 0.5436 | Val Loss: 0.0015
# EarlyStopping counter: 1/20
# Epoch [52/100] | Train Loss: 0.5417 | Val Loss: 0.0015
# EarlyStopping counter: 2/20
# Epoch [53/100] | Train Loss: 0.5379 | Val Loss: 0.0015
# EarlyStopping counter: 3/20
# Epoch [54/100] | Train Loss: 0.5391 | Val Loss: 0.0015
# EarlyStopping counter: 4/20
# Epoch [55/100] | Train Loss: 0.5365 | Val Loss: 0.0015
# Checkpoint saved! (val_loss: 0.0015)
# Epoch [56/100] | Train Loss: 0.5362 | Val Loss: 0.0015
# Checkpoint saved! (val_loss: 0.0015)
# Epoch [57/100] | Train Loss: 0.5329 | Val Loss: 0.0015
# EarlyStopping counter: 1/20
# Epoch [58/100] | Train Loss: 0.5331 | Val Loss: 0.0015
# EarlyStopping counter: 2/20
# Epoch [59/100] | Train Loss: 0.5320 | Val Loss: 0.0015
# EarlyStopping counter: 3/20
# Epoch [60/100] | Train Loss: 0.5306 | Val Loss: 0.0015
# EarlyStopping counter: 4/20
# Epoch [61/100] | Train Loss: 0.5305 | Val Loss: 0.0015
# EarlyStopping counter: 5/20
# Epoch [62/100] | Train Loss: 0.5292 | Val Loss: 0.0015
# Checkpoint saved! (val_loss: 0.0015)
# Epoch [63/100] | Train Loss: 0.5272 | Val Loss: 0.0014
# Checkpoint saved! (val_loss: 0.0014)
# Epoch [64/100] | Train Loss: 0.5269 | Val Loss: 0.0015
# EarlyStopping counter: 1/20
# Epoch [65/100] | Train Loss: 0.5267 | Val Loss: 0.0015
# EarlyStopping counter: 2/20
# Epoch [66/100] | Train Loss: 0.5247 | Val Loss: 0.0015
# EarlyStopping counter: 3/20
# Epoch [67/100] | Train Loss: 0.5225 | Val Loss: 0.0014
# Checkpoint saved! (val_loss: 0.0014)
# Epoch [68/100] | Train Loss: 0.5213 | Val Loss: 0.0014
# Checkpoint saved! (val_loss: 0.0014)
# Epoch [69/100] | Train Loss: 0.5198 | Val Loss: 0.0014
# Checkpoint saved! (val_loss: 0.0014)
# Epoch [70/100] | Train Loss: 0.5217 | Val Loss: 0.0014
# EarlyStopping counter: 1/20
# Epoch [71/100] | Train Loss: 0.5187 | Val Loss: 0.0014
# Checkpoint saved! (val_loss: 0.0014)
# Epoch [72/100] | Train Loss: 0.5191 | Val Loss: 0.0014
# EarlyStopping counter: 1/20
# Epoch [73/100] | Train Loss: 0.5197 | Val Loss: 0.0014
# EarlyStopping counter: 2/20
# Epoch [74/100] | Train Loss: 0.5169 | Val Loss: 0.0014
# EarlyStopping counter: 3/20
# Epoch [75/100] | Train Loss: 0.5153 | Val Loss: 0.0015
# EarlyStopping counter: 4/20
# Epoch [76/100] | Train Loss: 0.5147 | Val Loss: 0.0014
# EarlyStopping counter: 5/20
# Epoch [77/100] | Train Loss: 0.5153 | Val Loss: 0.0014
# EarlyStopping counter: 6/20
# Epoch [78/100] | Train Loss: 0.5142 | Val Loss: 0.0014
# EarlyStopping counter: 7/20
# Epoch [79/100] | Train Loss: 0.5142 | Val Loss: 0.0014
# Checkpoint saved! (val_loss: 0.0014)
# Epoch [80/100] | Train Loss: 0.5128 | Val Loss: 0.0015
# EarlyStopping counter: 1/20
# Epoch [81/100] | Train Loss: 0.5131 | Val Loss: 0.0014
# EarlyStopping counter: 2/20
# Epoch [82/100] | Train Loss: 0.5125 | Val Loss: 0.0014
# EarlyStopping counter: 3/20
# Epoch [83/100] | Train Loss: 0.5110 | Val Loss: 0.0014
# EarlyStopping counter: 4/20
# Epoch [84/100] | Train Loss: 0.5118 | Val Loss: 0.0014
# Checkpoint saved! (val_loss: 0.0014)
# Epoch [85/100] | Train Loss: 0.5085 | Val Loss: 0.0014
# EarlyStopping counter: 1/20
# Epoch [86/100] | Train Loss: 0.5114 | Val Loss: 0.0014
# EarlyStopping counter: 2/20
# Epoch [87/100] | Train Loss: 0.5096 | Val Loss: 0.0014
# EarlyStopping counter: 3/20
# Epoch [88/100] | Train Loss: 0.5104 | Val Loss: 0.0014
# EarlyStopping counter: 4/20
# Epoch [89/100] | Train Loss: 0.5045 | Val Loss: 0.0014
# EarlyStopping counter: 5/20
# Epoch [90/100] | Train Loss: 0.5049 | Val Loss: 0.0014
# EarlyStopping counter: 6/20
# Epoch [91/100] | Train Loss: 0.5060 | Val Loss: 0.0014
# EarlyStopping counter: 7/20
# Epoch [92/100] | Train Loss: 0.5067 | Val Loss: 0.0014
# EarlyStopping counter: 8/20
# Epoch [93/100] | Train Loss: 0.5037 | Val Loss: 0.0014
# EarlyStopping counter: 9/20
# Epoch [94/100] | Train Loss: 0.5040 | Val Loss: 0.0014
# EarlyStopping counter: 10/20
# Epoch [95/100] | Train Loss: 0.5027 | Val Loss: 0.0014
# EarlyStopping counter: 11/20
# Epoch [96/100] | Train Loss: 0.5030 | Val Loss: 0.0014
# EarlyStopping counter: 12/20
# Epoch [97/100] | Train Loss: 0.5026 | Val Loss: 0.0014
# EarlyStopping counter: 13/20
# Epoch [98/100] | Train Loss: 0.5022 | Val Loss: 0.0014
# EarlyStopping counter: 14/20
# Epoch [99/100] | Train Loss: 0.5022 | Val Loss: 0.0014
# EarlyStopping counter: 15/20
# Epoch [100/100] | Train Loss: 0.5023 | Val Loss: 0.0014
# EarlyStopping counter: 16/20
# ============================================================
# TRAINING COMPLETED
# Best validation loss: 0.0014
# ============================================================
# ------------------------------------------------------------
# [6/16] Testing: {'l1_lambda': 0.0, 'l2_lambda': 0.01, 'dropout_rate': 0.2, 'lr': 0.0005}
# Weights initialized using kaiming method
# ============================================================
# TRAINING STARTED
# ============================================================
# Epoch [ 1/100] | Train Loss: 2.1294 | Val Loss: 0.0090
# Checkpoint saved! (val_loss: 0.0090)
# Epoch [ 2/100] | Train Loss: 1.6919 | Val Loss: 0.0068
# Checkpoint saved! (val_loss: 0.0068)
# Epoch [ 3/100] | Train Loss: 1.4299 | Val Loss: 0.0054
# Checkpoint saved! (val_loss: 0.0054)
# Epoch [ 4/100] | Train Loss: 1.2559 | Val Loss: 0.0046
# Checkpoint saved! (val_loss: 0.0046)
# Epoch [ 5/100] | Train Loss: 1.1501 | Val Loss: 0.0041
# Checkpoint saved! (val_loss: 0.0041)
# Epoch [ 6/100] | Train Loss: 1.0804 | Val Loss: 0.0038
# Checkpoint saved! (val_loss: 0.0038)
# Epoch [ 7/100] | Train Loss: 1.0196 | Val Loss: 0.0035
# Checkpoint saved! (val_loss: 0.0035)
# Epoch [ 8/100] | Train Loss: 0.9816 | Val Loss: 0.0033
# Checkpoint saved! (val_loss: 0.0033)
# ...
# Checkpoint saved! (val_loss: 0.0018)
# Epoch [31/100] | Train Loss: 1.5131 | Val Loss: 0.0018
# Checkpoint saved! (val_loss: 0.0018)
# Epoch [32/100] | Train Loss: 1.5036 | Val Loss: 0.0018
# Checkpoint saved! (val_loss: 0.0018)
# Epoch [33/100] | Train Loss: 1.4929 | Val Loss: 0.0018
# EarlyStopping counter: 1/20
# Epoch [34/100] | Train Loss: 1.4779 | Val Loss: 0.0017
# Checkpoint saved! (val_loss: 0.0017)
# Epoch [35/100] | Train Loss: 1.4692 | Val Loss: 0.0017
# Checkpoint saved! (val_loss: 0.0017)
# Epoch [36/100] | Train Loss: 1.4571 | Val Loss: 0.0017
# Checkpoint saved! (val_loss: 0.0017)
# Epoch [37/100] | Train Loss: 1.4435 | Val Loss: 0.0017
# Checkpoint saved! (val_loss: 0.0017)
# Epoch [38/100] | Train Loss: 1.4342 | Val Loss: 0.0017
# EarlyStopping counter: 1/20
# Epoch [39/100] | Train Loss: 1.4271 | Val Loss: 0.0017
# Checkpoint saved! (val_loss: 0.0017)
# Epoch [40/100] | Train Loss: 1.4161 | Val Loss: 0.0017
# EarlyStopping counter: 1/20
# Epoch [41/100] | Train Loss: 1.4058 | Val Loss: 0.0017
# Checkpoint saved! (val_loss: 0.0017)
# Epoch [42/100] | Train Loss: 1.3931 | Val Loss: 0.0017
# Checkpoint saved! (val_loss: 0.0017)
# Epoch [43/100] | Train Loss: 1.3842 | Val Loss: 0.0017
# Checkpoint saved! (val_loss: 0.0017)
# Epoch [44/100] | Train Loss: 1.3755 | Val Loss: 0.0017
# EarlyStopping counter: 1/20
# Epoch [45/100] | Train Loss: 1.3678 | Val Loss: 0.0016
# Checkpoint saved! (val_loss: 0.0016)
# Epoch [46/100] | Train Loss: 1.3580 | Val Loss: 0.0016
# EarlyStopping counter: 1/20
# Epoch [47/100] | Train Loss: 1.3483 | Val Loss: 0.0016
# Checkpoint saved! (val_loss: 0.0016)
# Epoch [48/100] | Train Loss: 1.3380 | Val Loss: 0.0016
# Checkpoint saved! (val_loss: 0.0016)
# Epoch [49/100] | Train Loss: 1.3282 | Val Loss: 0.0016
# EarlyStopping counter: 1/20
# Epoch [50/100] | Train Loss: 1.3194 | Val Loss: 0.0016
# Checkpoint saved! (val_loss: 0.0016)
# Epoch [51/100] | Train Loss: 1.3123 | Val Loss: 0.0016
# EarlyStopping counter: 1/20
# Epoch [52/100] | Train Loss: 1.3062 | Val Loss: 0.0016
# Checkpoint saved! (val_loss: 0.0016)
# Epoch [53/100] | Train Loss: 1.2976 | Val Loss: 0.0016
# Checkpoint saved! (val_loss: 0.0016)
# Epoch [54/100] | Train Loss: 1.2879 | Val Loss: 0.0016
# Checkpoint saved! (val_loss: 0.0016)
# Epoch [55/100] | Train Loss: 1.2788 | Val Loss: 0.0016
# Checkpoint saved! (val_loss: 0.0016)
# Epoch [56/100] | Train Loss: 1.2725 | Val Loss: 0.0016
# Checkpoint saved! (val_loss: 0.0016)
# Epoch [57/100] | Train Loss: 1.2634 | Val Loss: 0.0016
# EarlyStopping counter: 1/20
# Epoch [58/100] | Train Loss: 1.2578 | Val Loss: 0.0016
# EarlyStopping counter: 2/20
# Epoch [59/100] | Train Loss: 1.2488 | Val Loss: 0.0016
# EarlyStopping counter: 3/20
# Epoch [60/100] | Train Loss: 1.2395 | Val Loss: 0.0016
# EarlyStopping counter: 4/20
# Epoch [61/100] | Train Loss: 1.2335 | Val Loss: 0.0016
# Checkpoint saved! (val_loss: 0.0016)
# Epoch [62/100] | Train Loss: 1.2268 | Val Loss: 0.0016
# Checkpoint saved! (val_loss: 0.0016)
# Epoch [63/100] | Train Loss: 1.2184 | Val Loss: 0.0016
# EarlyStopping counter: 1/20
# Epoch [64/100] | Train Loss: 1.2100 | Val Loss: 0.0016
# EarlyStopping counter: 2/20
# Epoch [65/100] | Train Loss: 1.2060 | Val Loss: 0.0015
# Checkpoint saved! (val_loss: 0.0015)
# Epoch [66/100] | Train Loss: 1.1956 | Val Loss: 0.0015
# Checkpoint saved! (val_loss: 0.0015)
# Epoch [67/100] | Train Loss: 1.1908 | Val Loss: 0.0015
# EarlyStopping counter: 1/20
# Epoch [68/100] | Train Loss: 1.1819 | Val Loss: 0.0015
# EarlyStopping counter: 2/20
# Epoch [69/100] | Train Loss: 1.1765 | Val Loss: 0.0015
# EarlyStopping counter: 3/20
# Epoch [70/100] | Train Loss: 1.1687 | Val Loss: 0.0015
# EarlyStopping counter: 4/20
# Epoch [71/100] | Train Loss: 1.1637 | Val Loss: 0.0015
# EarlyStopping counter: 5/20
# Epoch [72/100] | Train Loss: 1.1568 | Val Loss: 0.0015
# Checkpoint saved! (val_loss: 0.0015)
# Epoch [73/100] | Train Loss: 1.1499 | Val Loss: 0.0015
# Checkpoint saved! (val_loss: 0.0015)
# Epoch [74/100] | Train Loss: 1.1437 | Val Loss: 0.0015
# Checkpoint saved! (val_loss: 0.0015)
# Epoch [75/100] | Train Loss: 1.1365 | Val Loss: 0.0015
# EarlyStopping counter: 1/20
# Epoch [76/100] | Train Loss: 1.1299 | Val Loss: 0.0015
# EarlyStopping counter: 2/20
# Epoch [77/100] | Train Loss: 1.1248 | Val Loss: 0.0015
# EarlyStopping counter: 3/20
# Epoch [78/100] | Train Loss: 1.1190 | Val Loss: 0.0015
# Checkpoint saved! (val_loss: 0.0015)
# Epoch [79/100] | Train Loss: 1.1136 | Val Loss: 0.0015
# EarlyStopping counter: 1/20
# Epoch [80/100] | Train Loss: 1.1059 | Val Loss: 0.0015
# EarlyStopping counter: 2/20
# Epoch [81/100] | Train Loss: 1.1007 | Val Loss: 0.0015
# Checkpoint saved! (val_loss: 0.0015)
# Epoch [82/100] | Train Loss: 1.0957 | Val Loss: 0.0015
# EarlyStopping counter: 1/20
# Epoch [83/100] | Train Loss: 1.0890 | Val Loss: 0.0015
# EarlyStopping counter: 2/20
# Epoch [84/100] | Train Loss: 1.0822 | Val Loss: 0.0015
# EarlyStopping counter: 3/20
# Epoch [85/100] | Train Loss: 1.0789 | Val Loss: 0.0015
# EarlyStopping counter: 4/20
# Epoch [86/100] | Train Loss: 1.0701 | Val Loss: 0.0015
# Checkpoint saved! (val_loss: 0.0015)
# Epoch [87/100] | Train Loss: 1.0654 | Val Loss: 0.0015
# EarlyStopping counter: 1/20
# Epoch [88/100] | Train Loss: 1.0620 | Val Loss: 0.0015
# EarlyStopping counter: 2/20
# Epoch [89/100] | Train Loss: 1.0583 | Val Loss: 0.0015
# EarlyStopping counter: 3/20
# Epoch [90/100] | Train Loss: 1.0491 | Val Loss: 0.0015
# EarlyStopping counter: 4/20
# Epoch [91/100] | Train Loss: 1.0419 | Val Loss: 0.0015
# EarlyStopping counter: 5/20
# Epoch [92/100] | Train Loss: 1.0386 | Val Loss: 0.0015
# EarlyStopping counter: 6/20
# Epoch [93/100] | Train Loss: 1.0356 | Val Loss: 0.0015
# EarlyStopping counter: 7/20
# Epoch [94/100] | Train Loss: 1.0286 | Val Loss: 0.0015
# Checkpoint saved! (val_loss: 0.0015)
# Epoch [95/100] | Train Loss: 1.0243 | Val Loss: 0.0015
# EarlyStopping counter: 1/20
# Epoch [96/100] | Train Loss: 1.0197 | Val Loss: 0.0015
# EarlyStopping counter: 2/20
# Epoch [97/100] | Train Loss: 1.0136 | Val Loss: 0.0015
# EarlyStopping counter: 3/20
# Epoch [98/100] | Train Loss: 1.0093 | Val Loss: 0.0015
# EarlyStopping counter: 4/20
# Epoch [99/100] | Train Loss: 1.0043 | Val Loss: 0.0015
# EarlyStopping counter: 5/20
# Epoch [100/100] | Train Loss: 0.9988 | Val Loss: 0.0015
# EarlyStopping counter: 6/20
# ============================================================
# TRAINING COMPLETED
# Best validation loss: 0.0015
# ============================================================
# ------------------------------------------------------------
# [16/16] Testing: {'l1_lambda': 0.0001, 'l2_lambda': 0.01, 'dropout_rate': 0.3, 'lr': 0.0005}
# Weights initialized using kaiming method
# ============================================================
# TRAINING STARTED
# ============================================================
# Epoch [ 1/100] | Train Loss: 3.2513 | Val Loss: 0.0084
# Checkpoint saved! (val_loss: 0.0084)
# Epoch [ 2/100] | Train Loss: 2.8147 | Val Loss: 0.0064
# Checkpoint saved! (val_loss: 0.0064)
# Epoch [ 3/100] | Train Loss: 2.5767 | Val Loss: 0.0053
# Checkpoint saved! (val_loss: 0.0053)
# Epoch [ 4/100] | Train Loss: 2.4268 | Val Loss: 0.0046
# Checkpoint saved! (val_loss: 0.0046)
# Epoch [ 5/100] | Train Loss: 2.3289 | Val Loss: 0.0042
# Checkpoint saved! (val_loss: 0.0042)
# Epoch [ 6/100] | Train Loss: 2.2576 | Val Loss: 0.0038
# Checkpoint saved! (val_loss: 0.0038)
# Epoch [ 7/100] | Train Loss: 2.1956 | Val Loss: 0.0036
# Checkpoint saved! (val_loss: 0.0036)
# Epoch [ 8/100] | Train Loss: 2.1481 | Val Loss: 0.0034
# Checkpoint saved! (val_loss: 0.0034)
# Epoch [ 9/100] | Train Loss: 2.1095 | Val Loss: 0.0033
# Checkpoint saved! (val_loss: 0.0033)
# Epoch [10/100] | Train Loss: 2.0762 | Val Loss: 0.0032
# Checkpoint saved! (val_loss: 0.0032)
# Epoch [11/100] | Train Loss: 2.0475 | Val Loss: 0.0031
# Checkpoint saved! (val_loss: 0.0031)
# Epoch [12/100] | Train Loss: 2.0127 | Val Loss: 0.0030
# Checkpoint saved! (val_loss: 0.0030)
# Epoch [13/100] | Train Loss: 1.9925 | Val Loss: 0.0029
# Checkpoint saved! (val_loss: 0.0029)
# Epoch [14/100] | Train Loss: 1.9694 | Val Loss: 0.0029
# Checkpoint saved! (val_loss: 0.0029)
# Epoch [15/100] | Train Loss: 1.9536 | Val Loss: 0.0028
# Checkpoint saved! (val_loss: 0.0028)
# Epoch [16/100] | Train Loss: 1.9291 | Val Loss: 0.0027
# Checkpoint saved! (val_loss: 0.0027)
# Epoch [17/100] | Train Loss: 1.9130 | Val Loss: 0.0027
# Checkpoint saved! (val_loss: 0.0027)
# Epoch [18/100] | Train Loss: 1.8964 | Val Loss: 0.0027
# Checkpoint saved! (val_loss: 0.0027)
# Epoch [19/100] | Train Loss: 1.8816 | Val Loss: 0.0026
# Checkpoint saved! (val_loss: 0.0026)
# Epoch [20/100] | Train Loss: 1.8629 | Val Loss: 0.0026
# Checkpoint saved! (val_loss: 0.0026)
# Epoch [21/100] | Train Loss: 1.8527 | Val Loss: 0.0026
# Checkpoint saved! (val_loss: 0.0026)
# Epoch [22/100] | Train Loss: 1.8393 | Val Loss: 0.0025
# Checkpoint saved! (val_loss: 0.0025)
# Epoch [23/100] | Train Loss: 1.8262 | Val Loss: 0.0025
# Checkpoint saved! (val_loss: 0.0025)
# Epoch [24/100] | Train Loss: 1.8121 | Val Loss: 0.0024
# Checkpoint saved! (val_loss: 0.0024)
# Epoch [25/100] | Train Loss: 1.8001 | Val Loss: 0.0024
# Checkpoint saved! (val_loss: 0.0024)
# Epoch [26/100] | Train Loss: 1.7893 | Val Loss: 0.0024
# Checkpoint saved! (val_loss: 0.0024)
# Epoch [27/100] | Train Loss: 1.7802 | Val Loss: 0.0023
# Checkpoint saved! (val_loss: 0.0023)
# Epoch [28/100] | Train Loss: 1.7662 | Val Loss: 0.0023
# Checkpoint saved! (val_loss: 0.0023)
# Epoch [29/100] | Train Loss: 1.7581 | Val Loss: 0.0023
# Checkpoint saved! (val_loss: 0.0023)
# Epoch [30/100] | Train Loss: 1.7500 | Val Loss: 0.0023
# Checkpoint saved! (val_loss: 0.0023)
# Epoch [31/100] | Train Loss: 1.7374 | Val Loss: 0.0023
# Checkpoint saved! (val_loss: 0.0023)
# Epoch [32/100] | Train Loss: 1.7253 | Val Loss: 0.0022
# Checkpoint saved! (val_loss: 0.0022)
# Epoch [33/100] | Train Loss: 1.7164 | Val Loss: 0.0022
# Checkpoint saved! (val_loss: 0.0022)
# Epoch [34/100] | Train Loss: 1.7103 | Val Loss: 0.0022
# EarlyStopping counter: 1/20
# Epoch [35/100] | Train Loss: 1.6995 | Val Loss: 0.0022
# Checkpoint saved! (val_loss: 0.0022)
# Epoch [36/100] | Train Loss: 1.6918 | Val Loss: 0.0022
# Checkpoint saved! (val_loss: 0.0022)
# Epoch [37/100] | Train Loss: 1.6851 | Val Loss: 0.0022
# Checkpoint saved! (val_loss: 0.0022)
# Epoch [38/100] | Train Loss: 1.6739 | Val Loss: 0.0021
# Checkpoint saved! (val_loss: 0.0021)
# Epoch [39/100] | Train Loss: 1.6679 | Val Loss: 0.0021
# EarlyStopping counter: 1/20
# Epoch [40/100] | Train Loss: 1.6576 | Val Loss: 0.0021
# Checkpoint saved! (val_loss: 0.0021)
# Epoch [41/100] | Train Loss: 1.6503 | Val Loss: 0.0021
# Checkpoint saved! (val_loss: 0.0021)
# Epoch [42/100] | Train Loss: 1.6415 | Val Loss: 0.0021
# Checkpoint saved! (val_loss: 0.0021)
# Epoch [43/100] | Train Loss: 1.6344 | Val Loss: 0.0021
# Checkpoint saved! (val_loss: 0.0021)
# Epoch [44/100] | Train Loss: 1.6257 | Val Loss: 0.0020
# Checkpoint saved! (val_loss: 0.0020)
# Epoch [45/100] | Train Loss: 1.6197 | Val Loss: 0.0020
# EarlyStopping counter: 1/20
# Epoch [46/100] | Train Loss: 1.6124 | Val Loss: 0.0020
# Checkpoint saved! (val_loss: 0.0020)
# Epoch [47/100] | Train Loss: 1.6030 | Val Loss: 0.0020
# Checkpoint saved! (val_loss: 0.0020)
# Epoch [48/100] | Train Loss: 1.5962 | Val Loss: 0.0020
# Checkpoint saved! (val_loss: 0.0020)
# Epoch [49/100] | Train Loss: 1.5889 | Val Loss: 0.0020
# Checkpoint saved! (val_loss: 0.0020)
# Epoch [50/100] | Train Loss: 1.5814 | Val Loss: 0.0020
# Checkpoint saved! (val_loss: 0.0020)
# Epoch [51/100] | Train Loss: 1.5802 | Val Loss: 0.0020
# Checkpoint saved! (val_loss: 0.0020)
# Epoch [52/100] | Train Loss: 1.5716 | Val Loss: 0.0019
# Checkpoint saved! (val_loss: 0.0019)
# Epoch [53/100] | Train Loss: 1.5653 | Val Loss: 0.0019
# EarlyStopping counter: 1/20
# Epoch [54/100] | Train Loss: 1.5572 | Val Loss: 0.0019
# Checkpoint saved! (val_loss: 0.0019)
# Epoch [55/100] | Train Loss: 1.5497 | Val Loss: 0.0019
# Checkpoint saved! (val_loss: 0.0019)
# Epoch [56/100] | Train Loss: 1.5437 | Val Loss: 0.0019
# Checkpoint saved! (val_loss: 0.0019)
# Epoch [57/100] | Train Loss: 1.5378 | Val Loss: 0.0019
# Checkpoint saved! (val_loss: 0.0019)
# Epoch [58/100] | Train Loss: 1.5347 | Val Loss: 0.0019
# EarlyStopping counter: 1/20
# Epoch [59/100] | Train Loss: 1.5272 | Val Loss: 0.0019
# Checkpoint saved! (val_loss: 0.0019)
# Epoch [60/100] | Train Loss: 1.5188 | Val Loss: 0.0019
# Checkpoint saved! (val_loss: 0.0019)
# Epoch [61/100] | Train Loss: 1.5137 | Val Loss: 0.0019
# Checkpoint saved! (val_loss: 0.0019)
# Epoch [62/100] | Train Loss: 1.5071 | Val Loss: 0.0019
# Checkpoint saved! (val_loss: 0.0019)
# Epoch [63/100] | Train Loss: 1.5018 | Val Loss: 0.0019
# EarlyStopping counter: 1/20
# Epoch [64/100] | Train Loss: 1.4965 | Val Loss: 0.0018
# Checkpoint saved! (val_loss: 0.0018)
# Epoch [65/100] | Train Loss: 1.4908 | Val Loss: 0.0018
# Checkpoint saved! (val_loss: 0.0018)
# Epoch [66/100] | Train Loss: 1.4847 | Val Loss: 0.0018
# Checkpoint saved! (val_loss: 0.0018)
# Epoch [67/100] | Train Loss: 1.4784 | Val Loss: 0.0018
# Checkpoint saved! (val_loss: 0.0018)
# Epoch [68/100] | Train Loss: 1.4750 | Val Loss: 0.0018
# EarlyStopping counter: 1/20
# Epoch [69/100] | Train Loss: 1.4652 | Val Loss: 0.0018
# Checkpoint saved! (val_loss: 0.0018)
# Epoch [70/100] | Train Loss: 1.4624 | Val Loss: 0.0018
# EarlyStopping counter: 1/20
# Epoch [71/100] | Train Loss: 1.4576 | Val Loss: 0.0018
# EarlyStopping counter: 2/20
# Epoch [72/100] | Train Loss: 1.4537 | Val Loss: 0.0018
# Checkpoint saved! (val_loss: 0.0018)
# Epoch [73/100] | Train Loss: 1.4466 | Val Loss: 0.0018
# EarlyStopping counter: 1/20
# Epoch [74/100] | Train Loss: 1.4382 | Val Loss: 0.0018
# EarlyStopping counter: 2/20
# Epoch [75/100] | Train Loss: 1.4363 | Val Loss: 0.0018
# Checkpoint saved! (val_loss: 0.0018)
# Epoch [76/100] | Train Loss: 1.4304 | Val Loss: 0.0018
# Checkpoint saved! (val_loss: 0.0018)
# Epoch [77/100] | Train Loss: 1.4258 | Val Loss: 0.0017
# Checkpoint saved! (val_loss: 0.0017)
# Epoch [78/100] | Train Loss: 1.4216 | Val Loss: 0.0017
# Checkpoint saved! (val_loss: 0.0017)
# Epoch [79/100] | Train Loss: 1.4157 | Val Loss: 0.0018
# EarlyStopping counter: 1/20
# Epoch [80/100] | Train Loss: 1.4122 | Val Loss: 0.0018
# EarlyStopping counter: 2/20
# Epoch [81/100] | Train Loss: 1.4066 | Val Loss: 0.0018
# EarlyStopping counter: 3/20
# Epoch [82/100] | Train Loss: 1.4025 | Val Loss: 0.0017
# Checkpoint saved! (val_loss: 0.0017)
# Epoch [83/100] | Train Loss: 1.3986 | Val Loss: 0.0017
# Checkpoint saved! (val_loss: 0.0017)
# Epoch [84/100] | Train Loss: 1.3913 | Val Loss: 0.0017
# EarlyStopping counter: 1/20
# Epoch [85/100] | Train Loss: 1.3844 | Val Loss: 0.0017
# EarlyStopping counter: 2/20
# Epoch [86/100] | Train Loss: 1.3831 | Val Loss: 0.0017
# EarlyStopping counter: 3/20
# Epoch [87/100] | Train Loss: 1.3795 | Val Loss: 0.0017
# Checkpoint saved! (val_loss: 0.0017)
# Epoch [88/100] | Train Loss: 1.3717 | Val Loss: 0.0017
# EarlyStopping counter: 1/20
# Epoch [89/100] | Train Loss: 1.3684 | Val Loss: 0.0017
# EarlyStopping counter: 2/20
# Epoch [90/100] | Train Loss: 1.3599 | Val Loss: 0.0017
# Checkpoint saved! (val_loss: 0.0017)
# Epoch [91/100] | Train Loss: 1.3605 | Val Loss: 0.0017
# Checkpoint saved! (val_loss: 0.0017)
# Epoch [92/100] | Train Loss: 1.3568 | Val Loss: 0.0017
# EarlyStopping counter: 1/20
# Epoch [93/100] | Train Loss: 1.3496 | Val Loss: 0.0017
# EarlyStopping counter: 2/20
# Epoch [94/100] | Train Loss: 1.3441 | Val Loss: 0.0017
# EarlyStopping counter: 3/20
# Epoch [95/100] | Train Loss: 1.3389 | Val Loss: 0.0017
# Checkpoint saved! (val_loss: 0.0017)
# Epoch [96/100] | Train Loss: 1.3392 | Val Loss: 0.0017
# EarlyStopping counter: 1/20
# Epoch [97/100] | Train Loss: 1.3338 | Val Loss: 0.0017
# EarlyStopping counter: 2/20
# Epoch [98/100] | Train Loss: 1.3286 | Val Loss: 0.0017
# Checkpoint saved! (val_loss: 0.0017)
# Epoch [99/100] | Train Loss: 1.3222 | Val Loss: 0.0017
# EarlyStopping counter: 1/20
# Epoch [100/100] | Train Loss: 1.3204 | Val Loss: 0.0016
# Checkpoint saved! (val_loss: 0.0016)
# ============================================================
# TRAINING COMPLETED
# Best validation loss: 0.0016
# ============================================================
# ------------------------------------------------------------
# Best Validation Loss: 0.0009
# Best Parameters: {'l1_lambda': 0.0, 'l2_lambda': 0.001, 'dropout_rate': 0.3, 'lr': 0.001}

# %% [markdown]
# ## Section 11: Hyperparameter Tuning - Random Search
#
# ### CONCEPT: Random Search
#
# Random Search samples **random combinations** from the hyperparameter space.

# %%
def random_search(param_grid, n_iterations=10):
    """
    Perform random search over hyperparameter space.
    It will look like grid search but you will sample random combinations.

    Args:
        param_grid: Dictionary of hyperparameter lists to sample from
        n_iterations: Number of random combinations to try

    Returns:
        best_model: Model with best validation loss
        best_params: Dictionary of best hyperparameters
    """
    # -------------------------------------------------------------------------
    # TODO 15: Implement random search
    # -------------------------------------------------------------------------

    pass

# %%
# best_model_random, best_params_random = random_search(param_grid, n_iterations=10)
# print("\nTesting best model from Random Search:")
# test_model(best_model_random)
